# %% [markdown]
# # Keyword Rank Analysis Report
#
# This report outlines the methodology and findings of the keyword rank analysis conducted in two main phases: initial analysis without removing duplicates and subsequent analysis with duplicate removal and spelling corrections. The objective is to understand the raw and adjusted impacts of keywords within our dataset.
#
# ## Phase 1: Analysis Without Removing Duplicates
#
# ### Semantic Analysis with Word Vectors
#
# - **Objective:** Utilize average word-to-vector representations for keywords to capture semantic meanings.
# - **Method:** Compare keywords using cosine similarity to rank them based on their semantic closeness.
#
# ### Sentence Occurrence Count
#
# - **Objective:** Identify sentences in `message.csv` containing any words present in `keyword.csv`.
# - **Method:** Count each sentence containing at least one keyword, treating multiple occurrences of the same keyword within a sentence as a single instance.
#
# ### Keyword Frequency Table
#
# - **Objective:** Quantify occurrences of each keyword within `message.csv`.
# - **Method:** Create a frequency table to analyze the distribution and prevalence of each keyword.
#
# ## Phase 2: Analysis with Duplicate Removal
#
# ### Removing Duplicate Sentences
#
# - **Objective:** Examine the impact of duplicate sentences on keyword significance.
# - **Method:** Identify and eliminate duplicate sentences from the dataset.
#
# ### Spelling Correction
#
# - **Objective:** Address spelling variations that may affect keyword detection and frequency counts.
# - **Method:** Apply a spelling checker to correct misspellings within the dataset.
#
# ### Re-evaluation of Keyword Significance
#
# - **Objective:** Reassess keyword significance post-cleanup.
# - **Method:** Repeat the semantic analysis, sentence occurrence count, and frequency table creation with the refined dataset.
# - **Comparison:** Evaluate the differences in keyword significance with and without duplicates, including the impacts of semantic analysis and spelling corrections.
#
# ## Comparison and Conclusions
#
# - **Findings:** Summarize the key differences observed between the two phases of analysis.
# - **Implications:** Discuss the implications of these findings on our understanding of keyword significance and ranking.
# - **Recommendations:** Provide recommendations based on the analysis outcomes.

# %%
# !pip install gensim
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: gensim in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (2.0.3)
# Requirement already satisfied: pyfume in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3)
# Requirement already satisfied: simpful in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.11.1)
# Requirement already satisfied: fst-pso in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)

# %%
# !pip install pyspellchecker
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pyspellchecker in /Users/bhaskaradhikari/anaconda3/lib/python3.11/site-packages (0.8.1)

# %%
import re
import numpy as np
from gensim.models import Word2Vec , KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
import pandas as pd

# %%
wv = KeyedVectors.load_word2vec_format('/Users/bhaskaradhikari/nlp/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
import numpy as np

df = pd.read_csv('/Users/bhaskaradhikari/nlp/Messages.csv')
df_key = pd.read_csv('/Users/bhaskaradhikari/nlp/Keywords.csv')

# %% [markdown]
# ### Phase 1: Analysis Without Removing Duplicates
# multiple same query can be happen and this data can be useful to rank the keyword .

# %%
#df = df.drop_duplicates(keep='first')
#df = df.reset_index(drop=True)

# %% [markdown]
# ### Preprocess sentences in the corpus

# %%
# Preprocess sentences in the corpus

corpus = []
lemmatizer = WordNetLemmatizer()
for i in range(len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['message'][i])
    review = review.lower().split()
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['desk',
#  'flat pack desk cupboard pedestal drawer',
#  'door step delivery',
#  'ground floor',
#  'number afraid wait web',
#  'day bed',
#  'yes frame single bed mattress',
#  'ground floor ground floor dismantled',
#  'bed frame dismantled mattress',
#  'specific time',
#  'yes please',
#  'ok wait confirmation thanks',
#  'business move large printer requiring four people lift shelving storage unit',
#  'first floor lift wide staircase',
#  'first floor lift',
#  'men',
#  'quote two people',
#  'confirm includes please',
#  'ok sorry think clear business move main item would item quite large heavy also forgot mention one printer round corner house l uh would also need add pick',
#  'paper drill mainly box storage unit desk',
#  'kg approx',
#  'king bed double bed cot single bed three seater sofa single seater sofa dinning table chair',
#  'kitchen item',
#  'ground floor apartment',
#  'lift',
#  'first floor',
#  'hello',
#  'piece suite',
#  'ground floor',
#  'ground floor',
#  'seater sofa armchair washing machine tumble dryer',
#  'nd floor lift',
#  'moving main door',
#  'thank get back later trouble sleeping regard cost moving new house lol',
#  'hi rob need check delivery made quote showing different price one quoted checking vat help',
#  'box suit case bag',
#  'ground floor',
#  'ground floor',
#  'g ub nx cost approximately',
#  'give booking date',
#  'ok fixed price please',
#  'send contact number',
#  'hi rob need pick cross trainer quit heavy',
#  'pick first floor drop shed',
#  'garage shed',
#  'better pallet truck lift tail lift van',
#  'weighs approx kg cm high x cm wide x cm long',
#  'fine ok',
#  'total cost wrexham bradford',
#  'approximately',
#  'much hour',
#  'drop back garden shed',
#  'mileage wrexham bradford x',
#  'mean total cost',
#  'oh sorry mistake one way',
#  'bought item yet need check still available home',
#  'touch later',
#  'thanks rob',
#  'hi rob three seater sofa two chair nest small table chest drawer l l two seat sofa l aw house l stair lift thanks',
#  'downstairs living room downstairs living room',
#  'definitely',
#  'double bed double wardrobe fridge freezer tumble drier bag item box suitcase coffee table corner unit sofa',
#  'ground floor st floor',
#  'lift',
#  'forgot tv stand',
#  'ok',
#  'ten box',
#  'seater seater sofa',
#  'still dont know price',
#  'one course',
#  'lawyer joke',
#  'quoted let settle mile',
#  'small double wardrobe chest drawer',
#  'bedroom bedroom',
#  'need check person buying',
#  'bungalow',
#  'ground floor flat stair leading flat',
#  'lift',
#  'thank',
#  'need full list',
#  'x bedroom apartment furniture item living room bedroom moving stuff storage serviced apartment block',
#  'also sutff small person office desk chair drawer cabinet',
#  'apology got called away still',
#  'double bed small piece wardrobe three seater two seater washing machine fridge',
#  'ground floor',
#  'ground floor stair',
#  'flexible',
#  'also small wall unit old time music gram',
#  'stone',
#  'might another trip b b move double bed base anyone actually speak',
#  'thank',
#  'bookcase ft wide ft need help moving leith',
#  'ground floor ground floor',
#  'thank flexible time pay',
#  'please confirm job',
#  'moving bought play house ride son need item moving isolating trying find cheap van po',
#  'much would please',
#  'plastic wendy house child ride',
#  'hello',
#  'hi van man hire edinburgh',
#  'cardboard box small medium fairly large case wheel soft rectangular case small holdall large material shoulder hag large plastic bag e g supermarket large size small plastic bag bean bag small arm chair small table',
#  'ground floor lift necessary',
#  'first floor lift',
#  'specific time',
#  'yes',
#  '',
#  'one flight stair',
#  'first floor',
#  'yes okay sure',
#  'tv',
#  'ground floor st floor',
#  'sure place lift find',
#  'sure time yet flexible',
#  'let check thing get back thank',
#  'bed mattress double single old carpet chair like van full stuff',
#  'yes',
#  'king size bed two double bed tv double seat chair waching manchine bag',
#  'lift',
#  'terrace house',
#  'terrace house',
#  'lift',
#  'approx box large tv tv stand bike x display cabinet medium mirror small mirror',
#  'first floor lift',
#  'ground floor',
#  'tell',
#  'specific time',
#  'single base bed l mattress l l',
#  'seeter sette chair',
#  'two seater sofa downstairs van council tip meanwood l book slot',
#  'upstairs bedroom first floor lift remove leg try chop bit',
#  'council tip section old furniture lift cylcling professional guide put old sofa',
#  'need registration van book slot council tip meanwood need time estimate',
#  'one level',
#  'desk one tv one treadmil big box one small cupboard',
#  'ground floor',
#  'make change',
#  'item need picked first floor lift dropped ground floor',
#  'tell ill wait',
#  'men pickup drop stuff',
#  'two seater sofa coffee table',
#  'desk',
#  'desk box',
#  'ground outside',
#  'st yes lift',
#  'reply please thank',
#  'tal email currently inaccessible',
#  'talitha golding',
#  'one seater sofa',
#  'ground floor',
#  'lift live ground floor',
#  'sure yet work rota due till tomorrow know day free',
#  'hi cot bed wardrobe changing table',
#  'husband friend help pick baby furniture',
#  'know never husband friend take furniture home van',
#  'ground floor',
#  'box washing machine table cm folding chair',
#  'double bed matress',
#  'yes',
#  'would say',
#  'first drop first floor apart stair',
#  'yes delivered first floor would like son old sofa picked brought house ground floor',
#  '',
#  'ok thanks gathering quote get back thank',
#  'industrial premise forklft forklift delivery end also',
#  'moving stuff flat bag',
#  'maybe',
#  'first floor take everything outside anyway people allowed building unless resident',
#  '',
#  '',
#  'ground floor',
#  '',
#  'yes',
#  'tv computer desk matress bicycle along box household item',
#  'furniture',
#  'small fridge freezer cooker washing machine',
#  'stair first floor',
#  'main door',
#  'thats much sorry try one else',
#  'double bed chest draw television computer table watching machine gaming chair tv stand saround sound speaker',
#  'lift get everything bottom taken front door',
#  'bed house bring everything upstairs stair removal people',
#  'ground floor',
#  'corner unit',
#  'sofa',
#  'front door st floor',
#  '',
#  'said boy carrying sofa van',
#  'yes',
#  'sorry already text',
#  'couple large box tv bike much',
#  'st floor lift',
#  'ground floor',
#  'seater sofa home daughter mile',
#  'nae exactly sure looking price',
#  'fridge freezer',
#  'minute finding',
#  'ground fooor',
#  'ground floor',
#  'lift',
#  'ground normal house',
#  'ok',
#  'iits ok thanks check seller',
#  'need van le au till naughbrough rd bag box full clothes sending charity',
#  'need hour',
#  '',
#  'ground floor',
#  'yeah double bed mattress',
#  'literally min drive',
#  'upstairs could bring',
#  'much',
#  'ground floor partner help wen get',
#  'let know',
#  'yes please',
#  'x seaters sofa',
#  'double door fridge freezer',
#  'gas cooker',
#  'x king size bed mattress single bed mattres',
#  'glass coffee table chest drawer',
#  'bed chest first floor everything else ground floor',
#  'lift',
#  'first floor bed chest rest groudfloor',
#  'lift',
#  'okay cool',
#  'flexible please',
#  'yes please',
#  'two seater sofa bed',
#  'first floor lift upper flat',
#  'delivery location ground floor may require take upstairs house',
#  '',
#  'specific time please',
#  'yes please',
#  'small seater couch please',
#  'table chair coffee table lamp table stand',
#  'tv',
#  'ground floor',
#  'ground floor',
#  'wait minute',
#  'thanks',
#  'pick one sofa',
#  '',
#  'ground level delivered ground level',
#  'double wardrobe',
#  'wardrobe',
#  'going find minute',
#  'house',
#  'assume floor',
#  'ground floor',
#  'flexible time',
#  'need know quote',
#  'helder',
#  'ftx ft green house piece',
#  'greenhouse garden',
#  'garden',
#  'seater curved sofa chair',
#  'ground floor house need lift',
#  'house lift needed',
#  'pallet',
#  'first floor',
#  '',
#  'ground floor lift',
#  'warehouse',
#  'hi',
#  'box wardrobe',
#  'clock',
#  'nd floor',
#  'secod floor lift stair',
#  'st floor lift',
#  'might',
#  'un assembled wardrobe night take person transfer rest manageable one person',
#  'roughly aprind box small one around',
#  'specific',
#  'like x box',
#  'would take one drop come decent size van',
#  'single bed mattress',
#  'first floor lift',
#  'ground floor',
#  'specific time please',
#  'yes please',
#  'pay driver day please',
#  'medium box suitcase medium object instrument',
#  'nd floor every item requires one person',
#  'understand fill form instead slow bot',
#  'item medium storage box another storage container',
#  'ground level',
#  'ground level',
#  'would like specific time organise actual date time',
#  'mr k hewitt',
#  'present zi know definitive time date',
#  'seater sofa split three able move think first floor flat delivered ground floor flat purchase gumtree',
#  'isnt',
#  'hi medium box large pc suitcase two bag',
#  'everything ground floor ready go',
#  'ground floor',
#  'fine',
#  'flexible work',
#  'bad bot flexible',
#  'would like total price quote',
#  'wardrobe',
#  'door wardrobe',
#  '',
#  'wardrobe mostly dismantled ground floor delivery also ground floor',
#  'planning buy one facebook idea sorry',
#  'hi rob',
#  'got exact postcode le fa could please let know price',
#  'flexible time fine',
#  'sorry name fatema mitaiwala',
#  'delivery home knighton',
#  'hi rob trying contact number belongs company please contact number thankyou',
#  'hi rob awaiting reply',
#  'please let know else see option',
#  'wanting peice suite delivery',
#  'ground floor delivery top floor modern block flat lift',
#  'floor',
#  'hi rob waiting text see price go specific time including vat',
#  'hi rob',
#  'coach',
#  'sofa chair sofa',
#  'ground floor house',
#  'much',
#  'normal house ground floor',
#  'said chair sofa',
#  'need know much please',
#  'x seater sofa',
#  'week',
#  'top floor lift',
#  'top',
#  '',
#  'text please',
#  'foot foot pool table leg come transport pool table house heavy like one pub',
#  'lift pick first floor flat delivery basement flat',
#  'medium box single mattress small table suitcase',
#  'apology hope still yes lift item would nd floor',
#  'test',
#  'first floor lift bunglow',
#  'yes',
#  'specific rob',
#  'person go van',
#  'yes',
#  'aaa ss',
#  'glass dining table',
#  'test',
#  'item sofa',
#  'ground floor',
#  'ground floor',
#  'chair',
#  'mattress bed frame sideboard bike',
#  'ground floor one item upstairs delivery address',
#  '',
#  'add chat',
#  'thanks come back',
#  'thanks get back',
#  'three seater sofa one armchair distance approx mile',
#  'pick delivery location main door ground floor',
#  'double mattress inch tv bed frame box box',
#  'bedside unit long standing unit',
#  'small arm chair',
#  'think everything',
#  'first floor',
#  'stair also back gate completely flat',
#  'lift nd floor flight stair',
#  'cabernet come piece',
#  'ground house',
#  'first gloor',
#  'ground floor',
#  'house',
#  'ty',
#  'specific time would price men please',
#  'get back u ty',
#  'plastic lightweight garden bench delivering coventry',
#  'side entry address ground floor garden coventry',
#  'noneed lift',
#  'moved garden entry effort ecpxtremily light',
#  'take minute take entry',
#  'thanks selling worth person asking pay delivery',
#  'say reduce arranges collection',
#  'interested buying garden plastic wood affect bench perfect condition thought may b able sell job',
#  'worry thought thanks time keep detail item family may need assistance',
#  'thanks',
#  'tv stand',
#  'decking',
#  'ground back property',
#  'dropped ground another property',
#  'suspect quite heavy pretty big bit decking railing aswell sure weight though',
#  'im trying find',
#  'suspect le ton lol',
#  'probably heavy maybe guess board metre length standard bade foundation dismantled standard railing heavy lift length board issue would estimated guess',
#  'worry know',
#  'fridge freezer king size bed bed side cabinet chest drawer double wardrobe small chair',
#  'pick first floor move third lift',
#  'test cust message',
#  'sofa mixed assortment furniture',
#  'pick point ol el know floor lift',
#  'drop first floor lift item seater sofa wardrobe bed collapsed microwave various household effect',
#  'get quote please',
#  'medium box several black bag item three larger item tv guitar bicycle',
#  'lift semi house item upstairs loft downstairs move item house needed',
#  'ground floor flat',
#  'wardrobe',
#  'stair',
#  'floor',
#  'stair',
#  'yes please',
#  'yes please',
#  'keith gray',
#  'much',
#  'wardrobe slim wardrobe',
#  'kingsize bed child bed dryer maybe bag',
#  'lift first floor',
#  'house converted flat shall stair flat',
#  'text please',
#  'want idea cost',
#  'thank leave thank time',
#  'digital piano otherwise furniture box book belonging probably fit small van started packing yet',
#  'first floor lift',
#  'btw hi real person',
#  'thanks',
#  'second floor lift',
#  'sorry really yet even started packing may need get back done estimate although say small van suffice',
#  'ok thanks help',
#  'one moment',
#  'say flexible time fine although would good keep flexible well e perhaps change specific advance warning',
#  'ok name pawel majecki',
#  'cancellation rescheduling policy',
#  'ok great think many thanks help',
#  'goodbye',
#  'fridge',
#  'sure',
#  'mattress washer dryer dressing table mirror seat',
#  'ground floor',
#  'ground floor',
#  'quote chat great thanks',
#  'would specific time would confirm estate agent',
#  'three seater sofa break two seater brake two rolled carpet tv tv stand box',
#  'load onto van',
#  'need help thank',
#  'living room ground floor',
#  'yeah nicole email address nicc seyg',
#  'confirm',
#  'okay thank',
#  'double bed',
#  'chair',
#  'street level going bunglow',
#  'fridge freezer',
#  'ground floor house house',
#  'stair lift',
#  'table chair bed',
#  '',
#  'street level',
#  'fridge',
#  '',
#  'street level',
#  'ground',
#  '',
#  'specific',
#  'yes',
#  'double bed sofa bed washing machine tumble dryer wardrobe chest drawer seat sofa arm chair',
#  'nope house house stair lift',
#  'sofa seater',
#  'st floor lift',
#  'ground',
#  '',
#  'flexible',
#  'yes',
#  '',
#  'yes aj',
#  'rob',
#  'one double mattress move',
#  'someone end help lifting drop end straight ground floor door fine',
#  'pick think second sure try',
#  'door',
#  'quote please',
#  'ground',
#  'thanks rob get back',
#  'bedroom house',
#  '',
#  'house item st floor',
#  'going bungalow',
#  '',
#  'specific',
#  'yes',
#  'qwe qwe',
#  'thanks',
#  'sorry l nz wn fq',
#  'would need help suitcase including garment bag packed nd floor apartment moving ground floor apartment',
#  'lift',
#  'yes',
#  'yes',
#  'specific time',
#  'van would',
#  'ok thanks suitcase garment bag large check size rest smaller one medium size one infant push chair hope would fit',
#  '',
#  'hidden charge quoted price inclusive charge including vat etc',
#  'give momenee moment',
#  'hi rob sorry long hold',
#  'please give quote suitcase infant push chair',
#  'reduced number baggage significantly expecting lower quote',
#  'yes please',
#  'sure thank',
#  'double chest drawer small bedside unit',
#  'th floor lift',
#  'house main door street upstairs flight stair bedroom',
#  'wide chest drawer like together',
#  'sorry expensive',
#  'bed house',
#  '',
#  'ground floor first floor house lift',
#  'ground floor lift',
#  '',
#  'seater sofa x king size bed x table chair',
#  'three seater sofa need move',
#  'ground floor',
#  'delivery location',
#  'sure',
#  'specific time',
#  'number call specify time know yet',
#  'ok thanks',
#  'dismantled garden shed approx flat load sise ftx',
#  'date',
#  'back garden b front garden b',
#  'lift involved',
#  'lift involved garden garden',
#  'double bed mattress bed side cabinet med fridge freezer tv inch tv unit one chest draw weight clothing box nick nacks black bin bag washing machine',
#  'first floor',
#  'lift',
#  'shed house storge',
#  'thank rob',
#  'specific time need leave time man van',
#  'would like know full cost first',
#  'colton york road',
#  'u le bed mattress side board box dressing table x bed side cabinet fridge freezer lamp double bed',
#  'x dressing table',
#  'garage ground floor ground floor storage unit',
#  'seater sofa seater sofa armchair',
#  'ground floor ground floor',
#  'ok',
#  'okay thanks much text detail get back',
#  'tv unit x x',
#  'ground floor',
#  'first floor lift',
#  'seater dining room table',
#  'lift delivery floor',
#  '',
#  'need someone collect display cabinet bt hh bt ax',
#  'first floor location',
#  'cabinet outside',
#  'ready picking',
#  'cabinet',
#  'ground floor',
#  'living room',
#  'moving item double bed mattress medium dining table medium box display unit chair inc tv small stand computer table large suite case medium bag',
#  'ground floor',
#  'ground floor',
#  'ok',
#  'check get back thanks',
#  'corner sofa table chair french dresser tv unit washing machine fridge freezer',
#  'sorry hold',
#  'stable matt garden box slim metal locker three bin',
#  'private stable yard bullens farm equestrian center',
#  'quote',
#  'lounge carpet distance mile price atm sister taking carpet fit car',
#  'main door main door carpet upstairs please bedroom',
#  'stored downstairs atm',
#  'best could',
#  'thanks come back know going ahead cheer',
#  'double bed seater sofa love seat table chair bedside drawer chest drawer kitchen equipment clothes',
#  'shelving unit',
#  'second floor flat property lift',
#  'large tv',
#  'ground',
#  'floor',
#  'floor lift',
#  'floor lift',
#  'get back thanks',
#  'would able pick item shop give detail guy shop would put van could help lift',
#  'would send receipt account detail etc',
#  'postcode shop',
#  'picnic bench',
#  'outside ground floor need hammer unclamp ground held strip metal teeth',
#  'one bed one wardrobe chest draw tv stand setee box one metal table barbecue pan one small fridge two tv',
#  'lift stair',
#  'first floor',
#  'semi detached house',
#  'first floor',
#  '',
#  'wardrobe x two need dismantling one double bed need dismantling sofa x dinning table need dismantling need removing',
#  'upstairs house',
#  'stair',
#  'double bed wardrobe washing machine fridge seater sofa seater sofa wall unit',
#  'flat tavners green handsworth wood b jj',
#  'deykin avenue witton b bg',
#  'large oak table mx plus extenders mx dining chair',
#  'ground floor house delivery ground floor house table disassembled leg',
#  'box flooring',
#  'single armchair',
#  'ground floor ground floor',
#  'think time flexible',
#  'give date please check pick time flexible think',
#  'please get back',
#  'thanks',
#  'x two seater sofa x kingzide bed mattress x double wardrobe chest drawer big box medium box kitchen table two chair',
#  'desk',
#  'small bookcase',
#  'rd floor lift moving st floor rd lift',
#  'nope email get back thanks',
#  'three seater seater king size bed two double bed washing macgine wardrob two drawer household',
#  'storage floor lift r first floor like bed near darnlay b q',
#  'much u charge may hour work',
#  'sofa seater seater bed one king size bed small double bed',
#  'call u later',
#  'sofa',
#  'ground floor',
#  'shed step ground floor',
#  'swivel chair',
#  'st',
#  'first floor',
#  '',
#  'lift',
#  'first floor lift',
#  'corner couch small unit',
#  'ground floor',
#  'ground floor lift main door house',
#  'wait thanks',
#  'specific time',
#  'give mobile number go payment',
#  'yes please',
#  'specific time',
#  'everything thanks',
#  'cash fine obviously paid advance',
#  'hi yeh moving new house double bed bedside cabinet kitchen stuff like microwave small appliance big bag clothes baby thing etc want roughly quots plz',
#  'ground floor',
#  'lift',
#  'cudnt u able roughly tell',
#  'u send cud text ther',
#  'g ex would need storage unit chest drawer double bed mattress glass display unit tv tv unit small coffee table moved would need seater couch moved g r delivery ml yr',
#  'g ex would first floor loft lift g r sure',
#  'box stuff friend',
#  'ordered new computer table book shelf wanted move still state delivered amazon',
#  'big cab',
#  'share picture package needed',
#  'please let know much would cost move send image mean email number',
#  'mine house ground floor onl destination lift apartment second floor',
#  'specific time give contact number confirm confirm friend thats',
#  'thats wanted confirm friend',
#  'cool contact one method',
#  'thanks quote contact confirmed friend',
#  'seater sofa seperated seat',
#  'ground floor',
#  'ground floor',
#  'wardrobe pick ikea sheffield home leicester',
#  'small bookcase small ikea bench one coffee table chair big box wardrobe chest drawer tbc please quote one include one without',
#  'would also wardrobe dismantled',
#  'thanks',
#  'rd lift rd lift',
#  'actually sorry please four quote',
#  'sorry would okay message get back',
#  'thanks lot',
#  'okay',
#  'tile replaced tile replaced old tile rubbish associated tile',
#  'chest drawer',
#  'move sofa',
#  'sure want lift deliver',
#  'think',
#  'none thank mile jorney',
#  '',
#  '',
#  'lt dd',
#  'seater sofa ottoman kingbed mattress x chest drawer seater dining table dressing room table tumble dryer two clothing rail',
#  'st floor lift',
#  'st floor lift',
#  'stair',
#  'ok quote get back touch liaising seller thanks book need confirm availability seller thanks quote return later',
#  'sure thing',
#  'sorry rob got disconnected',
#  'lift location current address floor destination address rd floor',
#  'listed inventory',
#  'travel suitcase wheel chair',
#  'computer table foldable ikea',
#  'dressing table side table',
#  'coffee table iron stand',
#  'around small box',
#  'carpet chest drawer',
#  'trolley foldable ikea',
#  'yee yes',
#  'hi',
#  'sofa fridge freeze cooker flat packed bed wardrobe like box',
#  'would st floor delivery address ground floor lift',
#  'okay great price number reference number quote go ahead',
#  'hi single item double bed frame dismantled',
#  'double bed frame',
#  'ground floor',
#  'ground floor',
#  'double bed mattress fridge freezer chest freezer seater corner sofa dining table chair triple wardrobe',
#  'pick house going storage unit ground floor',
#  'yes please',
#  'set drawer large footstool',
#  'ground floor ground floor',
#  'fitted wardrobe door',
#  'ground floor',
#  'ground floor',
#  'give quote please',
#  'quote',
#  'following delivery l could take wardrobe wf approx min away door wardrobe',
#  'would price please done',
#  'specific time could please',
#  'day',
#  'dee rigby',
#  'quite packed box small furniture item freezer plant garden item',
#  'detached house ground floor first floor',
#  'item going garage ground floor',
#  'think two',
#  'ab ht ab fj',
#  'swivel armchair',
#  'quote',
#  'ground floor lift end',
#  'nd quote',
#  'send please',
#  'need move large tv nothing else',
#  'moving ground floor',
#  'first floor',
#  'need carried stair require two peopls people',
#  'pickup eh sq going eh nb minute drive',
#  'sure',
#  'flexible time would fine need confirm person address would suitable',
#  'right come back quote',
#  'yes send detail would great want get another couple quote check friend availability price seems good',
#  'ok thanks',
#  'hi find reply need bed frame headboard foot bored mattress moving longsight reddish price please',
#  'dining table chair cambuslang summerston also single door wardrobe summerston summerston',
#  'ground floor ground floor',
#  'know start drumlaken street summerston g ph',
#  'specific time',
#  'give contact number confirm go ahead need discus person getting dining table best day',
#  'x mattress x bed part king bed x set drawer drawer inch tv boxed x tv speaker tv unit coffee table arm chair seater sofa one dining table built boxed one kitchen island medium box',
#  'ground',
#  'tell speaking robot human haha',
#  'moving first floor lift',
#  'good know thank',
#  'think would better',
#  'specific please',
#  'would need know conscious given list various random item suitcase bag know packed would case move list given',
#  'thank let know evening',
#  'cara',
#  'best get touch would work left chat open email number',
#  'seater sofa bit',
#  'main door first floor',
#  '',
#  'sofa come apart',
#  'first floor',
#  'lift',
#  'sure',
#  '',
#  'woman lift puece',
#  'big bed tv dining table chair luggage bag deep freezer small cloth packing stuff ground floor',
#  'l shape sofa',
#  '',
#  'street level',
#  'street level',
#  'fried freezer chest freezer washing machine double bed single bed pc sofa',
#  'one settee box',
#  'large box garage shelving',
#  'ground floor front shop',
#  'ground floor',
#  'live chat would fine',
#  'chat fine',
#  'appx guess',
#  'measure see fit space first get back',
#  'furniture clothes case couple box item',
#  'two seater sofa',
#  'small iron double bed frame',
#  'outside shed',
#  'ground floor',
#  'x three seater sofa',
#  'ground floor property',
#  'bed taken argyll place old bed taken tip portlethen',
#  'upstairs bed room stair semi detatched house',
#  'could possibly get taken downstairs',
#  'bed going skip coy',
#  'maybe taken downstairs',
#  'prob',
#  'one portlethen badentoy got post code',
#  'yes divan',
#  'bed address taken granddaughter address bed taken tip',
#  'address portlethen',
#  'flexible',
#  'speak granddaughter see price ok',
#  'check granddaughter might think dear',
#  'large fridge frezer',
#  'seater sofa swivel chair',
#  'house need pickup chipstead road b drop wendover road b',
#  'yes',
#  'reply email messenger',
#  'sound',
#  'thanks expensive thanks help',
#  'dinnig chair dinning table',
#  'hi tell charge',
#  'charge',
#  'washing machine wardrobe set drawer',
#  'getting moved ground floor flat positioned lift address',
#  'would',
#  'specific time',
#  'cross trainer',
#  'much charge',
#  'house st floor lift',
#  'know owner side',
#  'st floor lift',
#  'ask owner deliver ground floor',
#  'yes',
#  'hi dear',
#  'one item fridge fridge door one item',
#  'ground floor',
#  'need lift',
#  'item ground floor need lift',
#  'need lift ground floor',
#  'delivery adress ol pq',
#  'oua',
#  'fridge door',
#  'collect address wood crescent ol pq',
#  'dawi',
#  'yes mob number please',
#  'yes please',
#  'phone',
#  'one double bed mattress',
#  'third floor third floor lift help',
#  'pick g ea',
#  'drop g sorry wrote g accident earlier',
#  'g',
#  'minute need discus partner',
#  'look like good option need hour discus way get back phone e mail',
#  'yes thank thanks time',
#  'double bed x seater sofa',
#  'first floor bed ground getached house going second floor flat',
#  'lift',
#  'put thanks',
#  'flexible please ill give booking know price',
#  'yes',
#  'call mobile',
#  'corner sofa',
#  '',
#  'first floor lift',
#  'ground floor',
#  'pick eg bd delivery eh dw',
#  'sorry eh bd',
#  'flexible time',
#  'yes please',
#  'small seater sofa',
#  'main door',
#  'stair door',
#  'yes',
#  'sheet plasterboard',
#  'timber insulation',
#  'ground',
#  'ground end',
#  'corner sofa',
#  'lift taken round floor delivered ground floor',
#  'settee sofa bed',
#  'ground floor location',
#  'hour drive',
#  'could flexible',
#  'need think check option leave thanks prompt attention',
#  'two seater sofa',
#  'ground floor',
#  'lift',
#  'ground floor garage',
#  'lift ground',
#  'flexible',
#  'specific',
#  'would cost men please',
#  'pick carpet ft ft deliver south frederick street',
#  'mile wishal glasgow city centre',
#  'ive given u detail already',
#  'place gf dont know lady carpet bungalow',
#  'lift',
#  'one sofa seater',
#  'ground floor ground floor',
#  'yes please',
#  'yes',
#  'fridge freezer',
#  'rd floor beside lift',
#  'recycling centre palmerston road',
#  'yes',
#  'single bed single mattress fireplace',
#  'middle stair',
#  'first',
#  'house',
#  'cheaper',
#  'would need know would going could address',
#  'double wardrobe section plus door fitting',
#  'st floor flat',
#  '',
#  'house ground floor',
#  '',
#  'need make call first',
#  'corner sofa wardrobe drawer furniture fridge table',
#  'sofa chair stool hanging frame swinging chair',
#  'ground floor',
#  'ground floor',
#  'flexible time would ok get touch son give price thankyou much rob',
#  'item',
#  'single bed metre double bed metre fridge washing machine double set sofa wardrobe tv stand',
#  'much charge',
#  'pick floor',
#  'yes',
#  'pick dining table taunton deliver cv j',
#  'set date yet bought yet',
#  'seller household item imagine ground floor warehouse',
#  'bungalow',
#  'thank information contact successful',
#  'looking double bed mattress collected dunmurry newtownards cheer',
#  'st floor lift delivery',
#  'seater sofa seater',
#  'ground floor house ground floor house',
#  'please',
#  'flexible',
#  'approximately bin bag clothes box tv suitcase cheat drawer',
#  'st floor bedroom one flight stair lift happy move thing downstairs',
#  'say first floor',
#  '',
#  'bedroom shared house normal amount stair',
#  'st floor upstairs',
#  '',
#  'first floor lift',
#  'seater sofa seater sofa foot stool',
#  'first floor stair going house stair',
#  'yes like everything done',
#  'corner sofa washing machine fridge wall unit high bed',
#  'wardrobe box packed black bin bag',
#  'tv tv stand',
#  'lift stuff second floor',
#  'one high bed one wardrobe sendond floor',
#  'bed wardrobe upstairs everything else stair',
#  'chester draw upstairs well',
#  'sofa bed table chair favourite guitar',
#  'rd floor lift',
#  'lower ground yes lift work friday',
#  'need woman',
#  'know many lad would need',
#  'oh bless',
#  'anxiety issue',
#  'quote man',
#  'christmas special',
#  'also could sit van lad',
#  'okay fine pls book',
#  'one bed meter one freeze one dining table chair',
#  'yes need bit help bed freeze dining table open chair put self',
#  'house second floor lift',
#  'upstairs room bed freezer kitchen downstairs',
#  'much',
#  'problem thx rob',
#  'ok problem',
#  'ok problem send contact number call back rob many thx ur time',
#  'umm several box everyday thing clothes small cabinet desk disassemble large furniture say ish medium box',
#  'first flat st floor ground floor lift flat moving rd floor lift',
#  'choose specific get back time',
#  'specific please',
#  'yes please make booking',
#  'yes please',
#  'right back min',
#  'back',
#  'sorry made booking need anything else',
#  'ok thanks information thanks',
#  'see later',
#  'corner sofa',
#  'ground floor',
#  'second floor lift',
#  'tip transport looking get rid bedroom furniture wardrobe cheat drawer',
#  'house storey',
#  'nd',
#  'sofa chair footstool',
#  'seater couch',
#  'seater couch',
#  'flexable',
#  'house living room stair',
#  'lift needed groung level pick drop',
#  'use method',
#  'get back need consult seller get back soon speak',
#  'sorry giving number unti agreement would feel safer way',
#  'seater couch want picking delivering driver man',
#  'hello rob spoken lady said flexable fine would need driver helper',
#  'hello havn got back number',
#  'specific time slot please',
#  'one small two seater sofa',
#  'actually set time looking rough quote collect item via freecycle',
#  'get idea something becomes available',
#  'expect ground floor probably outside house',
#  'would first floor however stair leading house aswell',
#  'lift afraid',
#  'fine leave thank enough going',
#  'thank',
#  'sure',
#  'double size divan bed frame',
#  'give second confirm person getting item',
#  'anymore question need ask',
#  'ok im waiting reply',
#  'double sized divan bed frame item',
#  'yes lift bed frame nd floor put nd floor house',
#  'yes correct',
#  'sure',
#  'flexible time',
#  'thanks help',
#  'large chest drawer heavy armchair coffee table medium size lattice wooden box folding chair large framed picture coffee table',
#  ...]

# %%
# Preprocess keywords
corpus_key = []
for i in range(len(df_key)):
    review = re.sub('[^a-zA-Z0-9]', ' ', df_key['keyword'][i])
    review = review.lower().split()
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus_key.append(review)

# %%
corpus_key
# Out:
# ['basement',
#  'bungalow',
#  'delivery',
#  'downstair',
#  'front door',
#  'garage',
#  'garden',
#  'home',
#  'level',
#  'pavement',
#  'pickup',
#  'right',
#  'stair',
#  'storage',
#  'street level']

# %% [markdown]
# ### Tokenize sentences for Word2Vec training

# %%
# Tokenize sentences for Word2Vec training
tokens = [simple_preprocess(sentence) for sentence in corpus]

# Train Word2Vec model
model = Word2Vec(sentences=tokens, vector_size=100, window=5, min_count=1, workers=4)

# %%
tokens
# Out:
# [['desk'],
#  ['flat', 'pack', 'desk', 'cupboard', 'pedestal', 'drawer'],
#  ['door', 'step', 'delivery'],
#  ['ground', 'floor'],
#  ['number', 'afraid', 'wait', 'web'],
#  ['day', 'bed'],
#  ['yes', 'frame', 'single', 'bed', 'mattress'],
#  ['ground', 'floor', 'ground', 'floor', 'dismantled'],
#  ['bed', 'frame', 'dismantled', 'mattress'],
#  ['specific', 'time'],
#  ['yes', 'please'],
#  ['ok', 'wait', 'confirmation', 'thanks'],
#  ['business',
#   'move',
#   'large',
#   'printer',
#   'requiring',
#   'four',
#   'people',
#   'lift',
#   'shelving',
#   'storage',
#   'unit'],
#  ['first', 'floor', 'lift', 'wide', 'staircase'],
#  ['first', 'floor', 'lift'],
#  ['men'],
#  ['quote', 'two', 'people'],
#  ['confirm', 'includes', 'please'],
#  ['ok',
#   'sorry',
#   'think',
#   'clear',
#   'business',
#   'move',
#   'main',
#   'item',
#   'would',
#   'item',
#   'quite',
#   'large',
#   'heavy',
#   'also',
#   'forgot',
#   'mention',
#   'one',
#   'printer',
#   'round',
#   'corner',
#   'house',
#   'uh',
#   'would',
#   'also',
#   'need',
#   'add',
#   'pick'],
#  ['paper', 'drill', 'mainly', 'box', 'storage', 'unit', 'desk'],
#  ['kg', 'approx'],
#  ['king',
#   'bed',
#   'double',
#   'bed',
#   'cot',
#   'single',
#   'bed',
#   'three',
#   'seater',
#   'sofa',
#   'single',
#   'seater',
#   'sofa',
#   'dinning',
#   'table',
#   'chair'],
#  ['kitchen', 'item'],
#  ['ground', 'floor', 'apartment'],
#  ['lift'],
#  ['first', 'floor'],
#  ['hello'],
#  ['piece', 'suite'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['seater', 'sofa', 'armchair', 'washing', 'machine', 'tumble', 'dryer'],
#  ['nd', 'floor', 'lift'],
#  ['moving', 'main', 'door'],
#  ['thank',
#   'get',
#   'back',
#   'later',
#   'trouble',
#   'sleeping',
#   'regard',
#   'cost',
#   'moving',
#   'new',
#   'house',
#   'lol'],
#  ['hi',
#   'rob',
#   'need',
#   'check',
#   'delivery',
#   'made',
#   'quote',
#   'showing',
#   'different',
#   'price',
#   'one',
#   'quoted',
#   'checking',
#   'vat',
#   'help'],
#  ['box', 'suit', 'case', 'bag'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['ub', 'nx', 'cost', 'approximately'],
#  ['give', 'booking', 'date'],
#  ['ok', 'fixed', 'price', 'please'],
#  ['send', 'contact', 'number'],
#  ['hi', 'rob', 'need', 'pick', 'cross', 'trainer', 'quit', 'heavy'],
#  ['pick', 'first', 'floor', 'drop', 'shed'],
#  ['garage', 'shed'],
#  ['better', 'pallet', 'truck', 'lift', 'tail', 'lift', 'van'],
#  ['weighs', 'approx', 'kg', 'cm', 'high', 'cm', 'wide', 'cm', 'long'],
#  ['fine', 'ok'],
#  ['total', 'cost', 'wrexham', 'bradford'],
#  ['approximately'],
#  ['much', 'hour'],
#  ['drop', 'back', 'garden', 'shed'],
#  ['mileage', 'wrexham', 'bradford'],
#  ['mean', 'total', 'cost'],
#  ['oh', 'sorry', 'mistake', 'one', 'way'],
#  ['bought', 'item', 'yet', 'need', 'check', 'still', 'available', 'home'],
#  ['touch', 'later'],
#  ['thanks', 'rob'],
#  ['hi',
#   'rob',
#   'three',
#   'seater',
#   'sofa',
#   'two',
#   'chair',
#   'nest',
#   'small',
#   'table',
#   'chest',
#   'drawer',
#   'two',
#   'seat',
#   'sofa',
#   'aw',
#   'house',
#   'stair',
#   'lift',
#   'thanks'],
#  ['downstairs', 'living', 'room', 'downstairs', 'living', 'room'],
#  ['definitely'],
#  ['double',
#   'bed',
#   'double',
#   'wardrobe',
#   'fridge',
#   'freezer',
#   'tumble',
#   'drier',
#   'bag',
#   'item',
#   'box',
#   'suitcase',
#   'coffee',
#   'table',
#   'corner',
#   'unit',
#   'sofa'],
#  ['ground', 'floor', 'st', 'floor'],
#  ['lift'],
#  ['forgot', 'tv', 'stand'],
#  ['ok'],
#  ['ten', 'box'],
#  ['seater', 'seater', 'sofa'],
#  ['still', 'dont', 'know', 'price'],
#  ['one', 'course'],
#  ['lawyer', 'joke'],
#  ['quoted', 'let', 'settle', 'mile'],
#  ['small', 'double', 'wardrobe', 'chest', 'drawer'],
#  ['bedroom', 'bedroom'],
#  ['need', 'check', 'person', 'buying'],
#  ['bungalow'],
#  ['ground', 'floor', 'flat', 'stair', 'leading', 'flat'],
#  ['lift'],
#  ['thank'],
#  ['need', 'full', 'list'],
#  ['bedroom',
#   'apartment',
#   'furniture',
#   'item',
#   'living',
#   'room',
#   'bedroom',
#   'moving',
#   'stuff',
#   'storage',
#   'serviced',
#   'apartment',
#   'block'],
#  ['also',
#   'sutff',
#   'small',
#   'person',
#   'office',
#   'desk',
#   'chair',
#   'drawer',
#   'cabinet'],
#  ['apology', 'got', 'called', 'away', 'still'],
#  ['double',
#   'bed',
#   'small',
#   'piece',
#   'wardrobe',
#   'three',
#   'seater',
#   'two',
#   'seater',
#   'washing',
#   'machine',
#   'fridge'],
#  ['ground', 'floor'],
#  ['ground', 'floor', 'stair'],
#  ['flexible'],
#  ['also', 'small', 'wall', 'unit', 'old', 'time', 'music', 'gram'],
#  ['stone'],
#  ['might',
#   'another',
#   'trip',
#   'move',
#   'double',
#   'bed',
#   'base',
#   'anyone',
#   'actually',
#   'speak'],
#  ['thank'],
#  ['bookcase', 'ft', 'wide', 'ft', 'need', 'help', 'moving', 'leith'],
#  ['ground', 'floor', 'ground', 'floor'],
#  ['thank', 'flexible', 'time', 'pay'],
#  ['please', 'confirm', 'job'],
#  ['moving',
#   'bought',
#   'play',
#   'house',
#   'ride',
#   'son',
#   'need',
#   'item',
#   'moving',
#   'isolating',
#   'trying',
#   'find',
#   'cheap',
#   'van',
#   'po'],
#  ['much', 'would', 'please'],
#  ['plastic', 'wendy', 'house', 'child', 'ride'],
#  ['hello'],
#  ['hi', 'van', 'man', 'hire', 'edinburgh'],
#  ['cardboard',
#   'box',
#   'small',
#   'medium',
#   'fairly',
#   'large',
#   'case',
#   'wheel',
#   'soft',
#   'rectangular',
#   'case',
#   'small',
#   'holdall',
#   'large',
#   'material',
#   'shoulder',
#   'hag',
#   'large',
#   'plastic',
#   'bag',
#   'supermarket',
#   'large',
#   'size',
#   'small',
#   'plastic',
#   'bag',
#   'bean',
#   'bag',
#   'small',
#   'arm',
#   'chair',
#   'small',
#   'table'],
#  ['ground', 'floor', 'lift', 'necessary'],
#  ['first', 'floor', 'lift'],
#  ['specific', 'time'],
#  ['yes'],
#  [],
#  ['one', 'flight', 'stair'],
#  ['first', 'floor'],
#  ['yes', 'okay', 'sure'],
#  ['tv'],
#  ['ground', 'floor', 'st', 'floor'],
#  ['sure', 'place', 'lift', 'find'],
#  ['sure', 'time', 'yet', 'flexible'],
#  ['let', 'check', 'thing', 'get', 'back', 'thank'],
#  ['bed',
#   'mattress',
#   'double',
#   'single',
#   'old',
#   'carpet',
#   'chair',
#   'like',
#   'van',
#   'full',
#   'stuff'],
#  ['yes'],
#  ['king',
#   'size',
#   'bed',
#   'two',
#   'double',
#   'bed',
#   'tv',
#   'double',
#   'seat',
#   'chair',
#   'waching',
#   'manchine',
#   'bag'],
#  ['lift'],
#  ['terrace', 'house'],
#  ['terrace', 'house'],
#  ['lift'],
#  ['approx',
#   'box',
#   'large',
#   'tv',
#   'tv',
#   'stand',
#   'bike',
#   'display',
#   'cabinet',
#   'medium',
#   'mirror',
#   'small',
#   'mirror'],
#  ['first', 'floor', 'lift'],
#  ['ground', 'floor'],
#  ['tell'],
#  ['specific', 'time'],
#  ['single', 'base', 'bed', 'mattress'],
#  ['seeter', 'sette', 'chair'],
#  ['two',
#   'seater',
#   'sofa',
#   'downstairs',
#   'van',
#   'council',
#   'tip',
#   'meanwood',
#   'book',
#   'slot'],
#  ['upstairs',
#   'bedroom',
#   'first',
#   'floor',
#   'lift',
#   'remove',
#   'leg',
#   'try',
#   'chop',
#   'bit'],
#  ['council',
#   'tip',
#   'section',
#   'old',
#   'furniture',
#   'lift',
#   'cylcling',
#   'professional',
#   'guide',
#   'put',
#   'old',
#   'sofa'],
#  ['need',
#   'registration',
#   'van',
#   'book',
#   'slot',
#   'council',
#   'tip',
#   'meanwood',
#   'need',
#   'time',
#   'estimate'],
#  ['one', 'level'],
#  ['desk',
#   'one',
#   'tv',
#   'one',
#   'treadmil',
#   'big',
#   'box',
#   'one',
#   'small',
#   'cupboard'],
#  ['ground', 'floor'],
#  ['make', 'change'],
#  ['item',
#   'need',
#   'picked',
#   'first',
#   'floor',
#   'lift',
#   'dropped',
#   'ground',
#   'floor'],
#  ['tell', 'ill', 'wait'],
#  ['men', 'pickup', 'drop', 'stuff'],
#  ['two', 'seater', 'sofa', 'coffee', 'table'],
#  ['desk'],
#  ['desk', 'box'],
#  ['ground', 'outside'],
#  ['st', 'yes', 'lift'],
#  ['reply', 'please', 'thank'],
#  ['tal', 'email', 'currently', 'inaccessible'],
#  ['talitha', 'golding'],
#  ['one', 'seater', 'sofa'],
#  ['ground', 'floor'],
#  ['lift', 'live', 'ground', 'floor'],
#  ['sure',
#   'yet',
#   'work',
#   'rota',
#   'due',
#   'till',
#   'tomorrow',
#   'know',
#   'day',
#   'free'],
#  ['hi', 'cot', 'bed', 'wardrobe', 'changing', 'table'],
#  ['husband', 'friend', 'help', 'pick', 'baby', 'furniture'],
#  ['know', 'never', 'husband', 'friend', 'take', 'furniture', 'home', 'van'],
#  ['ground', 'floor'],
#  ['box', 'washing', 'machine', 'table', 'cm', 'folding', 'chair'],
#  ['double', 'bed', 'matress'],
#  ['yes'],
#  ['would', 'say'],
#  ['first', 'drop', 'first', 'floor', 'apart', 'stair'],
#  ['yes',
#   'delivered',
#   'first',
#   'floor',
#   'would',
#   'like',
#   'son',
#   'old',
#   'sofa',
#   'picked',
#   'brought',
#   'house',
#   'ground',
#   'floor'],
#  [],
#  ['ok', 'thanks', 'gathering', 'quote', 'get', 'back', 'thank'],
#  ['industrial', 'premise', 'forklft', 'forklift', 'delivery', 'end', 'also'],
#  ['moving', 'stuff', 'flat', 'bag'],
#  ['maybe'],
#  ['first',
#   'floor',
#   'take',
#   'everything',
#   'outside',
#   'anyway',
#   'people',
#   'allowed',
#   'building',
#   'unless',
#   'resident'],
#  [],
#  [],
#  ['ground', 'floor'],
#  [],
#  ['yes'],
#  ['tv',
#   'computer',
#   'desk',
#   'matress',
#   'bicycle',
#   'along',
#   'box',
#   'household',
#   'item'],
#  ['furniture'],
#  ['small', 'fridge', 'freezer', 'cooker', 'washing', 'machine'],
#  ['stair', 'first', 'floor'],
#  ['main', 'door'],
#  ['thats', 'much', 'sorry', 'try', 'one', 'else'],
#  ['double',
#   'bed',
#   'chest',
#   'draw',
#   'television',
#   'computer',
#   'table',
#   'watching',
#   'machine',
#   'gaming',
#   'chair',
#   'tv',
#   'stand',
#   'saround',
#   'sound',
#   'speaker'],
#  ['lift', 'get', 'everything', 'bottom', 'taken', 'front', 'door'],
#  ['bed',
#   'house',
#   'bring',
#   'everything',
#   'upstairs',
#   'stair',
#   'removal',
#   'people'],
#  ['ground', 'floor'],
#  ['corner', 'unit'],
#  ['sofa'],
#  ['front', 'door', 'st', 'floor'],
#  [],
#  ['said', 'boy', 'carrying', 'sofa', 'van'],
#  ['yes'],
#  ['sorry', 'already', 'text'],
#  ['couple', 'large', 'box', 'tv', 'bike', 'much'],
#  ['st', 'floor', 'lift'],
#  ['ground', 'floor'],
#  ['seater', 'sofa', 'home', 'daughter', 'mile'],
#  ['nae', 'exactly', 'sure', 'looking', 'price'],
#  ['fridge', 'freezer'],
#  ['minute', 'finding'],
#  ['ground', 'fooor'],
#  ['ground', 'floor'],
#  ['lift'],
#  ['ground', 'normal', 'house'],
#  ['ok'],
#  ['iits', 'ok', 'thanks', 'check', 'seller'],
#  ['need',
#   'van',
#   'le',
#   'au',
#   'till',
#   'naughbrough',
#   'rd',
#   'bag',
#   'box',
#   'full',
#   'clothes',
#   'sending',
#   'charity'],
#  ['need', 'hour'],
#  [],
#  ['ground', 'floor'],
#  ['yeah', 'double', 'bed', 'mattress'],
#  ['literally', 'min', 'drive'],
#  ['upstairs', 'could', 'bring'],
#  ['much'],
#  ['ground', 'floor', 'partner', 'help', 'wen', 'get'],
#  ['let', 'know'],
#  ['yes', 'please'],
#  ['seaters', 'sofa'],
#  ['double', 'door', 'fridge', 'freezer'],
#  ['gas', 'cooker'],
#  ['king', 'size', 'bed', 'mattress', 'single', 'bed', 'mattres'],
#  ['glass', 'coffee', 'table', 'chest', 'drawer'],
#  ['bed', 'chest', 'first', 'floor', 'everything', 'else', 'ground', 'floor'],
#  ['lift'],
#  ['first', 'floor', 'bed', 'chest', 'rest', 'groudfloor'],
#  ['lift'],
#  ['okay', 'cool'],
#  ['flexible', 'please'],
#  ['yes', 'please'],
#  ['two', 'seater', 'sofa', 'bed'],
#  ['first', 'floor', 'lift', 'upper', 'flat'],
#  ['delivery',
#   'location',
#   'ground',
#   'floor',
#   'may',
#   'require',
#   'take',
#   'upstairs',
#   'house'],
#  [],
#  ['specific', 'time', 'please'],
#  ['yes', 'please'],
#  ['small', 'seater', 'couch', 'please'],
#  ['table', 'chair', 'coffee', 'table', 'lamp', 'table', 'stand'],
#  ['tv'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['wait', 'minute'],
#  ['thanks'],
#  ['pick', 'one', 'sofa'],
#  [],
#  ['ground', 'level', 'delivered', 'ground', 'level'],
#  ['double', 'wardrobe'],
#  ['wardrobe'],
#  ['going', 'find', 'minute'],
#  ['house'],
#  ['assume', 'floor'],
#  ['ground', 'floor'],
#  ['flexible', 'time'],
#  ['need', 'know', 'quote'],
#  ['helder'],
#  ['ftx', 'ft', 'green', 'house', 'piece'],
#  ['greenhouse', 'garden'],
#  ['garden'],
#  ['seater', 'curved', 'sofa', 'chair'],
#  ['ground', 'floor', 'house', 'need', 'lift'],
#  ['house', 'lift', 'needed'],
#  ['pallet'],
#  ['first', 'floor'],
#  [],
#  ['ground', 'floor', 'lift'],
#  ['warehouse'],
#  ['hi'],
#  ['box', 'wardrobe'],
#  ['clock'],
#  ['nd', 'floor'],
#  ['secod', 'floor', 'lift', 'stair'],
#  ['st', 'floor', 'lift'],
#  ['might'],
#  ['un',
#   'assembled',
#   'wardrobe',
#   'night',
#   'take',
#   'person',
#   'transfer',
#   'rest',
#   'manageable',
#   'one',
#   'person'],
#  ['roughly', 'aprind', 'box', 'small', 'one', 'around'],
#  ['specific'],
#  ['like', 'box'],
#  ['would', 'take', 'one', 'drop', 'come', 'decent', 'size', 'van'],
#  ['single', 'bed', 'mattress'],
#  ['first', 'floor', 'lift'],
#  ['ground', 'floor'],
#  ['specific', 'time', 'please'],
#  ['yes', 'please'],
#  ['pay', 'driver', 'day', 'please'],
#  ['medium', 'box', 'suitcase', 'medium', 'object', 'instrument'],
#  ['nd', 'floor', 'every', 'item', 'requires', 'one', 'person'],
#  ['understand', 'fill', 'form', 'instead', 'slow', 'bot'],
#  ['item', 'medium', 'storage', 'box', 'another', 'storage', 'container'],
#  ['ground', 'level'],
#  ['ground', 'level'],
#  ['would', 'like', 'specific', 'time', 'organise', 'actual', 'date', 'time'],
#  ['mr', 'hewitt'],
#  ['present', 'zi', 'know', 'definitive', 'time', 'date'],
#  ['seater',
#   'sofa',
#   'split',
#   'three',
#   'able',
#   'move',
#   'think',
#   'first',
#   'floor',
#   'flat',
#   'delivered',
#   'ground',
#   'floor',
#   'flat',
#   'purchase',
#   'gumtree'],
#  ['isnt'],
#  ['hi', 'medium', 'box', 'large', 'pc', 'suitcase', 'two', 'bag'],
#  ['everything', 'ground', 'floor', 'ready', 'go'],
#  ['ground', 'floor'],
#  ['fine'],
#  ['flexible', 'work'],
#  ['bad', 'bot', 'flexible'],
#  ['would', 'like', 'total', 'price', 'quote'],
#  ['wardrobe'],
#  ['door', 'wardrobe'],
#  [],
#  ['wardrobe',
#   'mostly',
#   'dismantled',
#   'ground',
#   'floor',
#   'delivery',
#   'also',
#   'ground',
#   'floor'],
#  ['planning', 'buy', 'one', 'facebook', 'idea', 'sorry'],
#  ['hi', 'rob'],
#  ['got',
#   'exact',
#   'postcode',
#   'le',
#   'fa',
#   'could',
#   'please',
#   'let',
#   'know',
#   'price'],
#  ['flexible', 'time', 'fine'],
#  ['sorry', 'name', 'fatema', 'mitaiwala'],
#  ['delivery', 'home', 'knighton'],
#  ['hi',
#   'rob',
#   'trying',
#   'contact',
#   'number',
#   'belongs',
#   'company',
#   'please',
#   'contact',
#   'number',
#   'thankyou'],
#  ['hi', 'rob', 'awaiting', 'reply'],
#  ['please', 'let', 'know', 'else', 'see', 'option'],
#  ['wanting', 'peice', 'suite', 'delivery'],
#  ['ground',
#   'floor',
#   'delivery',
#   'top',
#   'floor',
#   'modern',
#   'block',
#   'flat',
#   'lift'],
#  ['floor'],
#  ['hi',
#   'rob',
#   'waiting',
#   'text',
#   'see',
#   'price',
#   'go',
#   'specific',
#   'time',
#   'including',
#   'vat'],
#  ['hi', 'rob'],
#  ['coach'],
#  ['sofa', 'chair', 'sofa'],
#  ['ground', 'floor', 'house'],
#  ['much'],
#  ['normal', 'house', 'ground', 'floor'],
#  ['said', 'chair', 'sofa'],
#  ['need', 'know', 'much', 'please'],
#  ['seater', 'sofa'],
#  ['week'],
#  ['top', 'floor', 'lift'],
#  ['top'],
#  [],
#  ['text', 'please'],
#  ['foot',
#   'foot',
#   'pool',
#   'table',
#   'leg',
#   'come',
#   'transport',
#   'pool',
#   'table',
#   'house',
#   'heavy',
#   'like',
#   'one',
#   'pub'],
#  ['lift', 'pick', 'first', 'floor', 'flat', 'delivery', 'basement', 'flat'],
#  ['medium', 'box', 'single', 'mattress', 'small', 'table', 'suitcase'],
#  ['apology', 'hope', 'still', 'yes', 'lift', 'item', 'would', 'nd', 'floor'],
#  ['test'],
#  ['first', 'floor', 'lift', 'bunglow'],
#  ['yes'],
#  ['specific', 'rob'],
#  ['person', 'go', 'van'],
#  ['yes'],
#  ['aaa', 'ss'],
#  ['glass', 'dining', 'table'],
#  ['test'],
#  ['item', 'sofa'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['chair'],
#  ['mattress', 'bed', 'frame', 'sideboard', 'bike'],
#  ['ground', 'floor', 'one', 'item', 'upstairs', 'delivery', 'address'],
#  [],
#  ['add', 'chat'],
#  ['thanks', 'come', 'back'],
#  ['thanks', 'get', 'back'],
#  ['three', 'seater', 'sofa', 'one', 'armchair', 'distance', 'approx', 'mile'],
#  ['pick', 'delivery', 'location', 'main', 'door', 'ground', 'floor'],
#  ['double', 'mattress', 'inch', 'tv', 'bed', 'frame', 'box', 'box'],
#  ['bedside', 'unit', 'long', 'standing', 'unit'],
#  ['small', 'arm', 'chair'],
#  ['think', 'everything'],
#  ['first', 'floor'],
#  ['stair', 'also', 'back', 'gate', 'completely', 'flat'],
#  ['lift', 'nd', 'floor', 'flight', 'stair'],
#  ['cabernet', 'come', 'piece'],
#  ['ground', 'house'],
#  ['first', 'gloor'],
#  ['ground', 'floor'],
#  ['house'],
#  ['ty'],
#  ['specific', 'time', 'would', 'price', 'men', 'please'],
#  ['get', 'back', 'ty'],
#  ['plastic', 'lightweight', 'garden', 'bench', 'delivering', 'coventry'],
#  ['side', 'entry', 'address', 'ground', 'floor', 'garden', 'coventry'],
#  ['noneed', 'lift'],
#  ['moved', 'garden', 'entry', 'effort', 'ecpxtremily', 'light'],
#  ['take', 'minute', 'take', 'entry'],
#  ['thanks', 'selling', 'worth', 'person', 'asking', 'pay', 'delivery'],
#  ['say', 'reduce', 'arranges', 'collection'],
#  ['interested',
#   'buying',
#   'garden',
#   'plastic',
#   'wood',
#   'affect',
#   'bench',
#   'perfect',
#   'condition',
#   'thought',
#   'may',
#   'able',
#   'sell',
#   'job'],
#  ['worry',
#   'thought',
#   'thanks',
#   'time',
#   'keep',
#   'detail',
#   'item',
#   'family',
#   'may',
#   'need',
#   'assistance'],
#  ['thanks'],
#  ['tv', 'stand'],
#  ['decking'],
#  ['ground', 'back', 'property'],
#  ['dropped', 'ground', 'another', 'property'],
#  ['suspect',
#   'quite',
#   'heavy',
#   'pretty',
#   'big',
#   'bit',
#   'decking',
#   'railing',
#   'aswell',
#   'sure',
#   'weight',
#   'though'],
#  ['im', 'trying', 'find'],
#  ['suspect', 'le', 'ton', 'lol'],
#  ['probably',
#   'heavy',
#   'maybe',
#   'guess',
#   'board',
#   'metre',
#   'length',
#   'standard',
#   'bade',
#   'foundation',
#   'dismantled',
#   'standard',
#   'railing',
#   'heavy',
#   'lift',
#   'length',
#   'board',
#   'issue',
#   'would',
#   'estimated',
#   'guess'],
#  ['worry', 'know'],
#  ['fridge',
#   'freezer',
#   'king',
#   'size',
#   'bed',
#   'bed',
#   'side',
#   'cabinet',
#   'chest',
#   'drawer',
#   'double',
#   'wardrobe',
#   'small',
#   'chair'],
#  ['pick', 'first', 'floor', 'move', 'third', 'lift'],
#  ['test', 'cust', 'message'],
#  ['sofa', 'mixed', 'assortment', 'furniture'],
#  ['pick', 'point', 'ol', 'el', 'know', 'floor', 'lift'],
#  ['drop',
#   'first',
#   'floor',
#   'lift',
#   'item',
#   'seater',
#   'sofa',
#   'wardrobe',
#   'bed',
#   'collapsed',
#   'microwave',
#   'various',
#   'household',
#   'effect'],
#  ['get', 'quote', 'please'],
#  ['medium',
#   'box',
#   'several',
#   'black',
#   'bag',
#   'item',
#   'three',
#   'larger',
#   'item',
#   'tv',
#   'guitar',
#   'bicycle'],
#  ['lift',
#   'semi',
#   'house',
#   'item',
#   'upstairs',
#   'loft',
#   'downstairs',
#   'move',
#   'item',
#   'house',
#   'needed'],
#  ['ground', 'floor', 'flat'],
#  ['wardrobe'],
#  ['stair'],
#  ['floor'],
#  ['stair'],
#  ['yes', 'please'],
#  ['yes', 'please'],
#  ['keith', 'gray'],
#  ['much'],
#  ['wardrobe', 'slim', 'wardrobe'],
#  ['kingsize', 'bed', 'child', 'bed', 'dryer', 'maybe', 'bag'],
#  ['lift', 'first', 'floor'],
#  ['house', 'converted', 'flat', 'shall', 'stair', 'flat'],
#  ['text', 'please'],
#  ['want', 'idea', 'cost'],
#  ['thank', 'leave', 'thank', 'time'],
#  ['digital',
#   'piano',
#   'otherwise',
#   'furniture',
#   'box',
#   'book',
#   'belonging',
#   'probably',
#   'fit',
#   'small',
#   'van',
#   'started',
#   'packing',
#   'yet'],
#  ['first', 'floor', 'lift'],
#  ['btw', 'hi', 'real', 'person'],
#  ['thanks'],
#  ['second', 'floor', 'lift'],
#  ['sorry',
#   'really',
#   'yet',
#   'even',
#   'started',
#   'packing',
#   'may',
#   'need',
#   'get',
#   'back',
#   'done',
#   'estimate',
#   'although',
#   'say',
#   'small',
#   'van',
#   'suffice'],
#  ['ok', 'thanks', 'help'],
#  ['one', 'moment'],
#  ['say',
#   'flexible',
#   'time',
#   'fine',
#   'although',
#   'would',
#   'good',
#   'keep',
#   'flexible',
#   'well',
#   'perhaps',
#   'change',
#   'specific',
#   'advance',
#   'warning'],
#  ['ok', 'name', 'pawel', 'majecki'],
#  ['cancellation', 'rescheduling', 'policy'],
#  ['ok', 'great', 'think', 'many', 'thanks', 'help'],
#  ['goodbye'],
#  ['fridge'],
#  ['sure'],
#  ['mattress', 'washer', 'dryer', 'dressing', 'table', 'mirror', 'seat'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['quote', 'chat', 'great', 'thanks'],
#  ['would', 'specific', 'time', 'would', 'confirm', 'estate', 'agent'],
#  ['three',
#   'seater',
#   'sofa',
#   'break',
#   'two',
#   'seater',
#   'brake',
#   'two',
#   'rolled',
#   'carpet',
#   'tv',
#   'tv',
#   'stand',
#   'box'],
#  ['load', 'onto', 'van'],
#  ['need', 'help', 'thank'],
#  ['living', 'room', 'ground', 'floor'],
#  ['yeah', 'nicole', 'email', 'address', 'nicc', 'seyg'],
#  ['confirm'],
#  ['okay', 'thank'],
#  ['double', 'bed'],
#  ['chair'],
#  ['street', 'level', 'going', 'bunglow'],
#  ['fridge', 'freezer'],
#  ['ground', 'floor', 'house', 'house'],
#  ['stair', 'lift'],
#  ['table', 'chair', 'bed'],
#  [],
#  ['street', 'level'],
#  ['fridge'],
#  [],
#  ['street', 'level'],
#  ['ground'],
#  [],
#  ['specific'],
#  ['yes'],
#  ['double',
#   'bed',
#   'sofa',
#   'bed',
#   'washing',
#   'machine',
#   'tumble',
#   'dryer',
#   'wardrobe',
#   'chest',
#   'drawer',
#   'seat',
#   'sofa',
#   'arm',
#   'chair'],
#  ['nope', 'house', 'house', 'stair', 'lift'],
#  ['sofa', 'seater'],
#  ['st', 'floor', 'lift'],
#  ['ground'],
#  [],
#  ['flexible'],
#  ['yes'],
#  [],
#  ['yes', 'aj'],
#  ['rob'],
#  ['one', 'double', 'mattress', 'move'],
#  ['someone',
#   'end',
#   'help',
#   'lifting',
#   'drop',
#   'end',
#   'straight',
#   'ground',
#   'floor',
#   'door',
#   'fine'],
#  ['pick', 'think', 'second', 'sure', 'try'],
#  ['door'],
#  ['quote', 'please'],
#  ['ground'],
#  ['thanks', 'rob', 'get', 'back'],
#  ['bedroom', 'house'],
#  [],
#  ['house', 'item', 'st', 'floor'],
#  ['going', 'bungalow'],
#  [],
#  ['specific'],
#  ['yes'],
#  ['qwe', 'qwe'],
#  ['thanks'],
#  ['sorry', 'nz', 'wn', 'fq'],
#  ['would',
#   'need',
#   'help',
#   'suitcase',
#   'including',
#   'garment',
#   'bag',
#   'packed',
#   'nd',
#   'floor',
#   'apartment',
#   'moving',
#   'ground',
#   'floor',
#   'apartment'],
#  ['lift'],
#  ['yes'],
#  ['yes'],
#  ['specific', 'time'],
#  ['van', 'would'],
#  ['ok',
#   'thanks',
#   'suitcase',
#   'garment',
#   'bag',
#   'large',
#   'check',
#   'size',
#   'rest',
#   'smaller',
#   'one',
#   'medium',
#   'size',
#   'one',
#   'infant',
#   'push',
#   'chair',
#   'hope',
#   'would',
#   'fit'],
#  [],
#  ['hidden',
#   'charge',
#   'quoted',
#   'price',
#   'inclusive',
#   'charge',
#   'including',
#   'vat',
#   'etc'],
#  ['give', 'momenee', 'moment'],
#  ['hi', 'rob', 'sorry', 'long', 'hold'],
#  ['please', 'give', 'quote', 'suitcase', 'infant', 'push', 'chair'],
#  ['reduced',
#   'number',
#   'baggage',
#   'significantly',
#   'expecting',
#   'lower',
#   'quote'],
#  ['yes', 'please'],
#  ['sure', 'thank'],
#  ['double', 'chest', 'drawer', 'small', 'bedside', 'unit'],
#  ['th', 'floor', 'lift'],
#  ['house', 'main', 'door', 'street', 'upstairs', 'flight', 'stair', 'bedroom'],
#  ['wide', 'chest', 'drawer', 'like', 'together'],
#  ['sorry', 'expensive'],
#  ['bed', 'house'],
#  [],
#  ['ground', 'floor', 'first', 'floor', 'house', 'lift'],
#  ['ground', 'floor', 'lift'],
#  [],
#  ['seater', 'sofa', 'king', 'size', 'bed', 'table', 'chair'],
#  ['three', 'seater', 'sofa', 'need', 'move'],
#  ['ground', 'floor'],
#  ['delivery', 'location'],
#  ['sure'],
#  ['specific', 'time'],
#  ['number', 'call', 'specify', 'time', 'know', 'yet'],
#  ['ok', 'thanks'],
#  ['dismantled', 'garden', 'shed', 'approx', 'flat', 'load', 'sise', 'ftx'],
#  ['date'],
#  ['back', 'garden', 'front', 'garden'],
#  ['lift', 'involved'],
#  ['lift', 'involved', 'garden', 'garden'],
#  ['double',
#   'bed',
#   'mattress',
#   'bed',
#   'side',
#   'cabinet',
#   'med',
#   'fridge',
#   'freezer',
#   'tv',
#   'inch',
#   'tv',
#   'unit',
#   'one',
#   'chest',
#   'draw',
#   'weight',
#   'clothing',
#   'box',
#   'nick',
#   'nacks',
#   'black',
#   'bin',
#   'bag',
#   'washing',
#   'machine'],
#  ['first', 'floor'],
#  ['lift'],
#  ['shed', 'house', 'storge'],
#  ['thank', 'rob'],
#  ['specific', 'time', 'need', 'leave', 'time', 'man', 'van'],
#  ['would', 'like', 'know', 'full', 'cost', 'first'],
#  ['colton', 'york', 'road'],
#  ['le',
#   'bed',
#   'mattress',
#   'side',
#   'board',
#   'box',
#   'dressing',
#   'table',
#   'bed',
#   'side',
#   'cabinet',
#   'fridge',
#   'freezer',
#   'lamp',
#   'double',
#   'bed'],
#  ['dressing', 'table'],
#  ['garage', 'ground', 'floor', 'ground', 'floor', 'storage', 'unit'],
#  ['seater', 'sofa', 'seater', 'sofa', 'armchair'],
#  ['ground', 'floor', 'ground', 'floor'],
#  ['ok'],
#  ['okay', 'thanks', 'much', 'text', 'detail', 'get', 'back'],
#  ['tv', 'unit'],
#  ['ground', 'floor'],
#  ['first', 'floor', 'lift'],
#  ['seater', 'dining', 'room', 'table'],
#  ['lift', 'delivery', 'floor'],
#  [],
#  ['need', 'someone', 'collect', 'display', 'cabinet', 'bt', 'hh', 'bt', 'ax'],
#  ['first', 'floor', 'location'],
#  ['cabinet', 'outside'],
#  ['ready', 'picking'],
#  ['cabinet'],
#  ['ground', 'floor'],
#  ['living', 'room'],
#  ['moving',
#   'item',
#   'double',
#   'bed',
#   'mattress',
#   'medium',
#   'dining',
#   'table',
#   'medium',
#   'box',
#   'display',
#   'unit',
#   'chair',
#   'inc',
#   'tv',
#   'small',
#   'stand',
#   'computer',
#   'table',
#   'large',
#   'suite',
#   'case',
#   'medium',
#   'bag'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['ok'],
#  ['check', 'get', 'back', 'thanks'],
#  ['corner',
#   'sofa',
#   'table',
#   'chair',
#   'french',
#   'dresser',
#   'tv',
#   'unit',
#   'washing',
#   'machine',
#   'fridge',
#   'freezer'],
#  ['sorry', 'hold'],
#  ['stable',
#   'matt',
#   'garden',
#   'box',
#   'slim',
#   'metal',
#   'locker',
#   'three',
#   'bin'],
#  ['private', 'stable', 'yard', 'bullens', 'farm', 'equestrian', 'center'],
#  ['quote'],
#  ['lounge',
#   'carpet',
#   'distance',
#   'mile',
#   'price',
#   'atm',
#   'sister',
#   'taking',
#   'carpet',
#   'fit',
#   'car'],
#  ['main', 'door', 'main', 'door', 'carpet', 'upstairs', 'please', 'bedroom'],
#  ['stored', 'downstairs', 'atm'],
#  ['best', 'could'],
#  ['thanks', 'come', 'back', 'know', 'going', 'ahead', 'cheer'],
#  ['double',
#   'bed',
#   'seater',
#   'sofa',
#   'love',
#   'seat',
#   'table',
#   'chair',
#   'bedside',
#   'drawer',
#   'chest',
#   'drawer',
#   'kitchen',
#   'equipment',
#   'clothes'],
#  ['shelving', 'unit'],
#  ['second', 'floor', 'flat', 'property', 'lift'],
#  ['large', 'tv'],
#  ['ground'],
#  ['floor'],
#  ['floor', 'lift'],
#  ['floor', 'lift'],
#  ['get', 'back', 'thanks'],
#  ['would',
#   'able',
#   'pick',
#   'item',
#   'shop',
#   'give',
#   'detail',
#   'guy',
#   'shop',
#   'would',
#   'put',
#   'van',
#   'could',
#   'help',
#   'lift'],
#  ['would', 'send', 'receipt', 'account', 'detail', 'etc'],
#  ['postcode', 'shop'],
#  ['picnic', 'bench'],
#  ['outside',
#   'ground',
#   'floor',
#   'need',
#   'hammer',
#   'unclamp',
#   'ground',
#   'held',
#   'strip',
#   'metal',
#   'teeth'],
#  ['one',
#   'bed',
#   'one',
#   'wardrobe',
#   'chest',
#   'draw',
#   'tv',
#   'stand',
#   'setee',
#   'box',
#   'one',
#   'metal',
#   'table',
#   'barbecue',
#   'pan',
#   'one',
#   'small',
#   'fridge',
#   'two',
#   'tv'],
#  ['lift', 'stair'],
#  ['first', 'floor'],
#  ['semi', 'detached', 'house'],
#  ['first', 'floor'],
#  [],
#  ['wardrobe',
#   'two',
#   'need',
#   'dismantling',
#   'one',
#   'double',
#   'bed',
#   'need',
#   'dismantling',
#   'sofa',
#   'dinning',
#   'table',
#   'need',
#   'dismantling',
#   'need',
#   'removing'],
#  ['upstairs', 'house'],
#  ['stair'],
#  ['double',
#   'bed',
#   'wardrobe',
#   'washing',
#   'machine',
#   'fridge',
#   'seater',
#   'sofa',
#   'seater',
#   'sofa',
#   'wall',
#   'unit'],
#  ['flat', 'tavners', 'green', 'handsworth', 'wood', 'jj'],
#  ['deykin', 'avenue', 'witton', 'bg'],
#  ['large', 'oak', 'table', 'mx', 'plus', 'extenders', 'mx', 'dining', 'chair'],
#  ['ground',
#   'floor',
#   'house',
#   'delivery',
#   'ground',
#   'floor',
#   'house',
#   'table',
#   'disassembled',
#   'leg'],
#  ['box', 'flooring'],
#  ['single', 'armchair'],
#  ['ground', 'floor', 'ground', 'floor'],
#  ['think', 'time', 'flexible'],
#  ['give', 'date', 'please', 'check', 'pick', 'time', 'flexible', 'think'],
#  ['please', 'get', 'back'],
#  ['thanks'],
#  ['two',
#   'seater',
#   'sofa',
#   'kingzide',
#   'bed',
#   'mattress',
#   'double',
#   'wardrobe',
#   'chest',
#   'drawer',
#   'big',
#   'box',
#   'medium',
#   'box',
#   'kitchen',
#   'table',
#   'two',
#   'chair'],
#  ['desk'],
#  ['small', 'bookcase'],
#  ['rd', 'floor', 'lift', 'moving', 'st', 'floor', 'rd', 'lift'],
#  ['nope', 'email', 'get', 'back', 'thanks'],
#  ['three',
#   'seater',
#   'seater',
#   'king',
#   'size',
#   'bed',
#   'two',
#   'double',
#   'bed',
#   'washing',
#   'macgine',
#   'wardrob',
#   'two',
#   'drawer',
#   'household'],
#  ['storage',
#   'floor',
#   'lift',
#   'first',
#   'floor',
#   'like',
#   'bed',
#   'near',
#   'darnlay'],
#  ['much', 'charge', 'may', 'hour', 'work'],
#  ['sofa',
#   'seater',
#   'seater',
#   'bed',
#   'one',
#   'king',
#   'size',
#   'bed',
#   'small',
#   'double',
#   'bed'],
#  ['call', 'later'],
#  ['sofa'],
#  ['ground', 'floor'],
#  ['shed', 'step', 'ground', 'floor'],
#  ['swivel', 'chair'],
#  ['st'],
#  ['first', 'floor'],
#  [],
#  ['lift'],
#  ['first', 'floor', 'lift'],
#  ['corner', 'couch', 'small', 'unit'],
#  ['ground', 'floor'],
#  ['ground', 'floor', 'lift', 'main', 'door', 'house'],
#  ['wait', 'thanks'],
#  ['specific', 'time'],
#  ['give', 'mobile', 'number', 'go', 'payment'],
#  ['yes', 'please'],
#  ['specific', 'time'],
#  ['everything', 'thanks'],
#  ['cash', 'fine', 'obviously', 'paid', 'advance'],
#  ['hi',
#   'yeh',
#   'moving',
#   'new',
#   'house',
#   'double',
#   'bed',
#   'bedside',
#   'cabinet',
#   'kitchen',
#   'stuff',
#   'like',
#   'microwave',
#   'small',
#   'appliance',
#   'big',
#   'bag',
#   'clothes',
#   'baby',
#   'thing',
#   'etc',
#   'want',
#   'roughly',
#   'quots',
#   'plz'],
#  ['ground', 'floor'],
#  ['lift'],
#  ['cudnt', 'able', 'roughly', 'tell'],
#  ['send', 'cud', 'text', 'ther'],
#  ['ex',
#   'would',
#   'need',
#   'storage',
#   'unit',
#   'chest',
#   'drawer',
#   'double',
#   'bed',
#   'mattress',
#   'glass',
#   'display',
#   'unit',
#   'tv',
#   'tv',
#   'unit',
#   'small',
#   'coffee',
#   'table',
#   'moved',
#   'would',
#   'need',
#   'seater',
#   'couch',
#   'moved',
#   'delivery',
#   'ml',
#   'yr'],
#  ['ex', 'would', 'first', 'floor', 'loft', 'lift', 'sure'],
#  ['box', 'stuff', 'friend'],
#  ['ordered',
#   'new',
#   'computer',
#   'table',
#   'book',
#   'shelf',
#   'wanted',
#   'move',
#   'still',
#   'state',
#   'delivered',
#   'amazon'],
#  ['big', 'cab'],
#  ['share', 'picture', 'package', 'needed'],
#  ['please',
#   'let',
#   'know',
#   'much',
#   'would',
#   'cost',
#   'move',
#   'send',
#   'image',
#   'mean',
#   'email',
#   'number'],
#  ['mine',
#   'house',
#   'ground',
#   'floor',
#   'onl',
#   'destination',
#   'lift',
#   'apartment',
#   'second',
#   'floor'],
#  ['specific',
#   'time',
#   'give',
#   'contact',
#   'number',
#   'confirm',
#   'confirm',
#   'friend',
#   'thats'],
#  ['thats', 'wanted', 'confirm', 'friend'],
#  ['cool', 'contact', 'one', 'method'],
#  ['thanks', 'quote', 'contact', 'confirmed', 'friend'],
#  ['seater', 'sofa', 'seperated', 'seat'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['wardrobe', 'pick', 'ikea', 'sheffield', 'home', 'leicester'],
#  ['small',
#   'bookcase',
#   'small',
#   'ikea',
#   'bench',
#   'one',
#   'coffee',
#   'table',
#   'chair',
#   'big',
#   'box',
#   'wardrobe',
#   'chest',
#   'drawer',
#   'tbc',
#   'please',
#   'quote',
#   'one',
#   'include',
#   'one',
#   'without'],
#  ['would', 'also', 'wardrobe', 'dismantled'],
#  ['thanks'],
#  ['rd', 'lift', 'rd', 'lift'],
#  ['actually', 'sorry', 'please', 'four', 'quote'],
#  ['sorry', 'would', 'okay', 'message', 'get', 'back'],
#  ['thanks', 'lot'],
#  ['okay'],
#  ['tile',
#   'replaced',
#   'tile',
#   'replaced',
#   'old',
#   'tile',
#   'rubbish',
#   'associated',
#   'tile'],
#  ['chest', 'drawer'],
#  ['move', 'sofa'],
#  ['sure', 'want', 'lift', 'deliver'],
#  ['think'],
#  ['none', 'thank', 'mile', 'jorney'],
#  [],
#  [],
#  ['lt', 'dd'],
#  ['seater',
#   'sofa',
#   'ottoman',
#   'kingbed',
#   'mattress',
#   'chest',
#   'drawer',
#   'seater',
#   'dining',
#   'table',
#   'dressing',
#   'room',
#   'table',
#   'tumble',
#   'dryer',
#   'two',
#   'clothing',
#   'rail'],
#  ['st', 'floor', 'lift'],
#  ['st', 'floor', 'lift'],
#  ['stair'],
#  ['ok',
#   'quote',
#   'get',
#   'back',
#   'touch',
#   'liaising',
#   'seller',
#   'thanks',
#   'book',
#   'need',
#   'confirm',
#   'availability',
#   'seller',
#   'thanks',
#   'quote',
#   'return',
#   'later'],
#  ['sure', 'thing'],
#  ['sorry', 'rob', 'got', 'disconnected'],
#  ['lift',
#   'location',
#   'current',
#   'address',
#   'floor',
#   'destination',
#   'address',
#   'rd',
#   'floor'],
#  ['listed', 'inventory'],
#  ['travel', 'suitcase', 'wheel', 'chair'],
#  ['computer', 'table', 'foldable', 'ikea'],
#  ['dressing', 'table', 'side', 'table'],
#  ['coffee', 'table', 'iron', 'stand'],
#  ['around', 'small', 'box'],
#  ['carpet', 'chest', 'drawer'],
#  ['trolley', 'foldable', 'ikea'],
#  ['yee', 'yes'],
#  ['hi'],
#  ['sofa',
#   'fridge',
#   'freeze',
#   'cooker',
#   'flat',
#   'packed',
#   'bed',
#   'wardrobe',
#   'like',
#   'box'],
#  ['would', 'st', 'floor', 'delivery', 'address', 'ground', 'floor', 'lift'],
#  ['okay',
#   'great',
#   'price',
#   'number',
#   'reference',
#   'number',
#   'quote',
#   'go',
#   'ahead'],
#  ['hi', 'single', 'item', 'double', 'bed', 'frame', 'dismantled'],
#  ['double', 'bed', 'frame'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['double',
#   'bed',
#   'mattress',
#   'fridge',
#   'freezer',
#   'chest',
#   'freezer',
#   'seater',
#   'corner',
#   'sofa',
#   'dining',
#   'table',
#   'chair',
#   'triple',
#   'wardrobe'],
#  ['pick', 'house', 'going', 'storage', 'unit', 'ground', 'floor'],
#  ['yes', 'please'],
#  ['set', 'drawer', 'large', 'footstool'],
#  ['ground', 'floor', 'ground', 'floor'],
#  ['fitted', 'wardrobe', 'door'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['give', 'quote', 'please'],
#  ['quote'],
#  ['following',
#   'delivery',
#   'could',
#   'take',
#   'wardrobe',
#   'wf',
#   'approx',
#   'min',
#   'away',
#   'door',
#   'wardrobe'],
#  ['would', 'price', 'please', 'done'],
#  ['specific', 'time', 'could', 'please'],
#  ['day'],
#  ['dee', 'rigby'],
#  ['quite',
#   'packed',
#   'box',
#   'small',
#   'furniture',
#   'item',
#   'freezer',
#   'plant',
#   'garden',
#   'item'],
#  ['detached', 'house', 'ground', 'floor', 'first', 'floor'],
#  ['item', 'going', 'garage', 'ground', 'floor'],
#  ['think', 'two'],
#  ['ab', 'ht', 'ab', 'fj'],
#  ['swivel', 'armchair'],
#  ['quote'],
#  ['ground', 'floor', 'lift', 'end'],
#  ['nd', 'quote'],
#  ['send', 'please'],
#  ['need', 'move', 'large', 'tv', 'nothing', 'else'],
#  ['moving', 'ground', 'floor'],
#  ['first', 'floor'],
#  ['need', 'carried', 'stair', 'require', 'two', 'peopls', 'people'],
#  ['pickup', 'eh', 'sq', 'going', 'eh', 'nb', 'minute', 'drive'],
#  ['sure'],
#  ['flexible',
#   'time',
#   'would',
#   'fine',
#   'need',
#   'confirm',
#   'person',
#   'address',
#   'would',
#   'suitable'],
#  ['right', 'come', 'back', 'quote'],
#  ['yes',
#   'send',
#   'detail',
#   'would',
#   'great',
#   'want',
#   'get',
#   'another',
#   'couple',
#   'quote',
#   'check',
#   'friend',
#   'availability',
#   'price',
#   'seems',
#   'good'],
#  ['ok', 'thanks'],
#  ['hi',
#   'find',
#   'reply',
#   'need',
#   'bed',
#   'frame',
#   'headboard',
#   'foot',
#   'bored',
#   'mattress',
#   'moving',
#   'longsight',
#   'reddish',
#   'price',
#   'please'],
#  ['dining',
#   'table',
#   'chair',
#   'cambuslang',
#   'summerston',
#   'also',
#   'single',
#   'door',
#   'wardrobe',
#   'summerston',
#   'summerston'],
#  ['ground', 'floor', 'ground', 'floor'],
#  ['know', 'start', 'drumlaken', 'street', 'summerston', 'ph'],
#  ['specific', 'time'],
#  ['give',
#   'contact',
#   'number',
#   'confirm',
#   'go',
#   'ahead',
#   'need',
#   'discus',
#   'person',
#   'getting',
#   'dining',
#   'table',
#   'best',
#   'day'],
#  ['mattress',
#   'bed',
#   'part',
#   'king',
#   'bed',
#   'set',
#   'drawer',
#   'drawer',
#   'inch',
#   'tv',
#   'boxed',
#   'tv',
#   'speaker',
#   'tv',
#   'unit',
#   'coffee',
#   'table',
#   'arm',
#   'chair',
#   'seater',
#   'sofa',
#   'one',
#   'dining',
#   'table',
#   'built',
#   'boxed',
#   'one',
#   'kitchen',
#   'island',
#   'medium',
#   'box'],
#  ['ground'],
#  ['tell', 'speaking', 'robot', 'human', 'haha'],
#  ['moving', 'first', 'floor', 'lift'],
#  ['good', 'know', 'thank'],
#  ['think', 'would', 'better'],
#  ['specific', 'please'],
#  ['would',
#   'need',
#   'know',
#   'conscious',
#   'given',
#   'list',
#   'various',
#   'random',
#   'item',
#   'suitcase',
#   'bag',
#   'know',
#   'packed',
#   'would',
#   'case',
#   'move',
#   'list',
#   'given'],
#  ['thank', 'let', 'know', 'evening'],
#  ['cara'],
#  ['best',
#   'get',
#   'touch',
#   'would',
#   'work',
#   'left',
#   'chat',
#   'open',
#   'email',
#   'number'],
#  ['seater', 'sofa', 'bit'],
#  ['main', 'door', 'first', 'floor'],
#  [],
#  ['sofa', 'come', 'apart'],
#  ['first', 'floor'],
#  ['lift'],
#  ['sure'],
#  [],
#  ['woman', 'lift', 'puece'],
#  ['big',
#   'bed',
#   'tv',
#   'dining',
#   'table',
#   'chair',
#   'luggage',
#   'bag',
#   'deep',
#   'freezer',
#   'small',
#   'cloth',
#   'packing',
#   'stuff',
#   'ground',
#   'floor'],
#  ['shape', 'sofa'],
#  [],
#  ['street', 'level'],
#  ['street', 'level'],
#  ['fried',
#   'freezer',
#   'chest',
#   'freezer',
#   'washing',
#   'machine',
#   'double',
#   'bed',
#   'single',
#   'bed',
#   'pc',
#   'sofa'],
#  ['one', 'settee', 'box'],
#  ['large', 'box', 'garage', 'shelving'],
#  ['ground', 'floor', 'front', 'shop'],
#  ['ground', 'floor'],
#  ['live', 'chat', 'would', 'fine'],
#  ['chat', 'fine'],
#  ['appx', 'guess'],
#  ['measure', 'see', 'fit', 'space', 'first', 'get', 'back'],
#  ['furniture', 'clothes', 'case', 'couple', 'box', 'item'],
#  ['two', 'seater', 'sofa'],
#  ['small', 'iron', 'double', 'bed', 'frame'],
#  ['outside', 'shed'],
#  ['ground', 'floor'],
#  ['three', 'seater', 'sofa'],
#  ['ground', 'floor', 'property'],
#  ['bed',
#   'taken',
#   'argyll',
#   'place',
#   'old',
#   'bed',
#   'taken',
#   'tip',
#   'portlethen'],
#  ['upstairs', 'bed', 'room', 'stair', 'semi', 'detatched', 'house'],
#  ['could', 'possibly', 'get', 'taken', 'downstairs'],
#  ['bed', 'going', 'skip', 'coy'],
#  ['maybe', 'taken', 'downstairs'],
#  ['prob'],
#  ['one', 'portlethen', 'badentoy', 'got', 'post', 'code'],
#  ['yes', 'divan'],
#  ['bed',
#   'address',
#   'taken',
#   'granddaughter',
#   'address',
#   'bed',
#   'taken',
#   'tip'],
#  ['address', 'portlethen'],
#  ['flexible'],
#  ['speak', 'granddaughter', 'see', 'price', 'ok'],
#  ['check', 'granddaughter', 'might', 'think', 'dear'],
#  ['large', 'fridge', 'frezer'],
#  ['seater', 'sofa', 'swivel', 'chair'],
#  ['house', 'need', 'pickup', 'chipstead', 'road', 'drop', 'wendover', 'road'],
#  ['yes'],
#  ['reply', 'email', 'messenger'],
#  ['sound'],
#  ['thanks', 'expensive', 'thanks', 'help'],
#  ['dinnig', 'chair', 'dinning', 'table'],
#  ['hi', 'tell', 'charge'],
#  ['charge'],
#  ['washing', 'machine', 'wardrobe', 'set', 'drawer'],
#  ['getting',
#   'moved',
#   'ground',
#   'floor',
#   'flat',
#   'positioned',
#   'lift',
#   'address'],
#  ['would'],
#  ['specific', 'time'],
#  ['cross', 'trainer'],
#  ['much', 'charge'],
#  ['house', 'st', 'floor', 'lift'],
#  ['know', 'owner', 'side'],
#  ['st', 'floor', 'lift'],
#  ['ask', 'owner', 'deliver', 'ground', 'floor'],
#  ['yes'],
#  ['hi', 'dear'],
#  ['one', 'item', 'fridge', 'fridge', 'door', 'one', 'item'],
#  ['ground', 'floor'],
#  ['need', 'lift'],
#  ['item', 'ground', 'floor', 'need', 'lift'],
#  ['need', 'lift', 'ground', 'floor'],
#  ['delivery', 'adress', 'ol', 'pq'],
#  ['oua'],
#  ['fridge', 'door'],
#  ['collect', 'address', 'wood', 'crescent', 'ol', 'pq'],
#  ['dawi'],
#  ['yes', 'mob', 'number', 'please'],
#  ['yes', 'please'],
#  ['phone'],
#  ['one', 'double', 'bed', 'mattress'],
#  ['third', 'floor', 'third', 'floor', 'lift', 'help'],
#  ['pick', 'ea'],
#  ['drop', 'sorry', 'wrote', 'accident', 'earlier'],
#  [],
#  ['minute', 'need', 'discus', 'partner'],
#  ['look',
#   'like',
#   'good',
#   'option',
#   'need',
#   'hour',
#   'discus',
#   'way',
#   'get',
#   'back',
#   'phone',
#   'mail'],
#  ['yes', 'thank', 'thanks', 'time'],
#  ['double', 'bed', 'seater', 'sofa'],
#  ['first',
#   'floor',
#   'bed',
#   'ground',
#   'getached',
#   'house',
#   'going',
#   'second',
#   'floor',
#   'flat'],
#  ['lift'],
#  ['put', 'thanks'],
#  ['flexible', 'please', 'ill', 'give', 'booking', 'know', 'price'],
#  ['yes'],
#  ['call', 'mobile'],
#  ['corner', 'sofa'],
#  [],
#  ['first', 'floor', 'lift'],
#  ['ground', 'floor'],
#  ['pick', 'eg', 'bd', 'delivery', 'eh', 'dw'],
#  ['sorry', 'eh', 'bd'],
#  ['flexible', 'time'],
#  ['yes', 'please'],
#  ['small', 'seater', 'sofa'],
#  ['main', 'door'],
#  ['stair', 'door'],
#  ['yes'],
#  ['sheet', 'plasterboard'],
#  ['timber', 'insulation'],
#  ['ground'],
#  ['ground', 'end'],
#  ['corner', 'sofa'],
#  ['lift', 'taken', 'round', 'floor', 'delivered', 'ground', 'floor'],
#  ['settee', 'sofa', 'bed'],
#  ['ground', 'floor', 'location'],
#  ['hour', 'drive'],
#  ['could', 'flexible'],
#  ['need',
#   'think',
#   'check',
#   'option',
#   'leave',
#   'thanks',
#   'prompt',
#   'attention'],
#  ['two', 'seater', 'sofa'],
#  ['ground', 'floor'],
#  ['lift'],
#  ['ground', 'floor', 'garage'],
#  ['lift', 'ground'],
#  ['flexible'],
#  ['specific'],
#  ['would', 'cost', 'men', 'please'],
#  ['pick', 'carpet', 'ft', 'ft', 'deliver', 'south', 'frederick', 'street'],
#  ['mile', 'wishal', 'glasgow', 'city', 'centre'],
#  ['ive', 'given', 'detail', 'already'],
#  ['place', 'gf', 'dont', 'know', 'lady', 'carpet', 'bungalow'],
#  ['lift'],
#  ['one', 'sofa', 'seater'],
#  ['ground', 'floor', 'ground', 'floor'],
#  ['yes', 'please'],
#  ['yes'],
#  ['fridge', 'freezer'],
#  ['rd', 'floor', 'beside', 'lift'],
#  ['recycling', 'centre', 'palmerston', 'road'],
#  ['yes'],
#  ['single', 'bed', 'single', 'mattress', 'fireplace'],
#  ['middle', 'stair'],
#  ['first'],
#  ['house'],
#  ['cheaper'],
#  ['would', 'need', 'know', 'would', 'going', 'could', 'address'],
#  ['double', 'wardrobe', 'section', 'plus', 'door', 'fitting'],
#  ['st', 'floor', 'flat'],
#  [],
#  ['house', 'ground', 'floor'],
#  [],
#  ['need', 'make', 'call', 'first'],
#  ['corner', 'sofa', 'wardrobe', 'drawer', 'furniture', 'fridge', 'table'],
#  ['sofa', 'chair', 'stool', 'hanging', 'frame', 'swinging', 'chair'],
#  ['ground', 'floor'],
#  ['ground', 'floor'],
#  ['flexible',
#   'time',
#   'would',
#   'ok',
#   'get',
#   'touch',
#   'son',
#   'give',
#   'price',
#   'thankyou',
#   'much',
#   'rob'],
#  ['item'],
#  ['single',
#   'bed',
#   'metre',
#   'double',
#   'bed',
#   'metre',
#   'fridge',
#   'washing',
#   'machine',
#   'double',
#   'set',
#   'sofa',
#   'wardrobe',
#   'tv',
#   'stand'],
#  ['much', 'charge'],
#  ['pick', 'floor'],
#  ['yes'],
#  ['pick', 'dining', 'table', 'taunton', 'deliver', 'cv'],
#  ['set', 'date', 'yet', 'bought', 'yet'],
#  ['seller', 'household', 'item', 'imagine', 'ground', 'floor', 'warehouse'],
#  ['bungalow'],
#  ['thank', 'information', 'contact', 'successful'],
#  ['looking',
#   'double',
#   'bed',
#   'mattress',
#   'collected',
#   'dunmurry',
#   'newtownards',
#   'cheer'],
#  ['st', 'floor', 'lift', 'delivery'],
#  ['seater', 'sofa', 'seater'],
#  ['ground', 'floor', 'house', 'ground', 'floor', 'house'],
#  ['please'],
#  ['flexible'],
#  ['approximately',
#   'bin',
#   'bag',
#   'clothes',
#   'box',
#   'tv',
#   'suitcase',
#   'cheat',
#   'drawer'],
#  ['st',
#   'floor',
#   'bedroom',
#   'one',
#   'flight',
#   'stair',
#   'lift',
#   'happy',
#   'move',
#   'thing',
#   'downstairs'],
#  ['say', 'first', 'floor'],
#  [],
#  ['bedroom', 'shared', 'house', 'normal', 'amount', 'stair'],
#  ['st', 'floor', 'upstairs'],
#  [],
#  ['first', 'floor', 'lift'],
#  ['seater', 'sofa', 'seater', 'sofa', 'foot', 'stool'],
#  ['first', 'floor', 'stair', 'going', 'house', 'stair'],
#  ['yes', 'like', 'everything', 'done'],
#  ['corner',
#   'sofa',
#   'washing',
#   'machine',
#   'fridge',
#   'wall',
#   'unit',
#   'high',
#   'bed'],
#  ['wardrobe', 'box', 'packed', 'black', 'bin', 'bag'],
#  ['tv', 'tv', 'stand'],
#  ['lift', 'stuff', 'second', 'floor'],
#  ['one', 'high', 'bed', 'one', 'wardrobe', 'sendond', 'floor'],
#  ['bed', 'wardrobe', 'upstairs', 'everything', 'else', 'stair'],
#  ['chester', 'draw', 'upstairs', 'well'],
#  ['sofa', 'bed', 'table', 'chair', 'favourite', 'guitar'],
#  ['rd', 'floor', 'lift'],
#  ['lower', 'ground', 'yes', 'lift', 'work', 'friday'],
#  ['need', 'woman'],
#  ['know', 'many', 'lad', 'would', 'need'],
#  ['oh', 'bless'],
#  ['anxiety', 'issue'],
#  ['quote', 'man'],
#  ['christmas', 'special'],
#  ['also', 'could', 'sit', 'van', 'lad'],
#  ['okay', 'fine', 'pls', 'book'],
#  ['one', 'bed', 'meter', 'one', 'freeze', 'one', 'dining', 'table', 'chair'],
#  ['yes',
#   'need',
#   'bit',
#   'help',
#   'bed',
#   'freeze',
#   'dining',
#   'table',
#   'open',
#   'chair',
#   'put',
#   'self'],
#  ['house', 'second', 'floor', 'lift'],
#  ['upstairs', 'room', 'bed', 'freezer', 'kitchen', 'downstairs'],
#  ['much'],
#  ['problem', 'thx', 'rob'],
#  ['ok', 'problem'],
#  ['ok',
#   'problem',
#   'send',
#   'contact',
#   'number',
#   'call',
#   'back',
#   'rob',
#   'many',
#   'thx',
#   'ur',
#   'time'],
#  ['umm',
#   'several',
#   'box',
#   'everyday',
#   'thing',
#   'clothes',
#   'small',
#   'cabinet',
#   'desk',
#   'disassemble',
#   'large',
#   'furniture',
#   'say',
#   'ish',
#   'medium',
#   'box'],
#  ['first',
#   'flat',
#   'st',
#   'floor',
#   'ground',
#   'floor',
#   'lift',
#   'flat',
#   'moving',
#   'rd',
#   'floor',
#   'lift'],
#  ['choose', 'specific', 'get', 'back', 'time'],
#  ['specific', 'please'],
#  ['yes', 'please', 'make', 'booking'],
#  ['yes', 'please'],
#  ['right', 'back', 'min'],
#  ['back'],
#  ['sorry', 'made', 'booking', 'need', 'anything', 'else'],
#  ['ok', 'thanks', 'information', 'thanks'],
#  ['see', 'later'],
#  ['corner', 'sofa'],
#  ['ground', 'floor'],
#  ['second', 'floor', 'lift'],
#  ['tip',
#   'transport',
#   'looking',
#   'get',
#   'rid',
#   'bedroom',
#   'furniture',
#   'wardrobe',
#   'cheat',
#   'drawer'],
#  ['house', 'storey'],
#  ['nd'],
#  ['sofa', 'chair', 'footstool'],
#  ['seater', 'couch'],
#  ['seater', 'couch'],
#  ['flexable'],
#  ['house', 'living', 'room', 'stair'],
#  ['lift', 'needed', 'groung', 'level', 'pick', 'drop'],
#  ['use', 'method'],
#  ['get', 'back', 'need', 'consult', 'seller', 'get', 'back', 'soon', 'speak'],
#  ['sorry',
#   'giving',
#   'number',
#   'unti',
#   'agreement',
#   'would',
#   'feel',
#   'safer',
#   'way'],
#  ['seater', 'couch', 'want', 'picking', 'delivering', 'driver', 'man'],
#  ['hello',
#   'rob',
#   'spoken',
#   'lady',
#   'said',
#   'flexable',
#   'fine',
#   'would',
#   'need',
#   'driver',
#   'helper'],
#  ['hello', 'havn', 'got', 'back', 'number'],
#  ['specific', 'time', 'slot', 'please'],
#  ['one', 'small', 'two', 'seater', 'sofa'],
#  ['actually',
#   'set',
#   'time',
#   'looking',
#   'rough',
#   'quote',
#   'collect',
#   'item',
#   'via',
#   'freecycle'],
#  ['get', 'idea', 'something', 'becomes', 'available'],
#  ['expect', 'ground', 'floor', 'probably', 'outside', 'house'],
#  ['would', 'first', 'floor', 'however', 'stair', 'leading', 'house', 'aswell'],
#  ['lift', 'afraid'],
#  ['fine', 'leave', 'thank', 'enough', 'going'],
#  ['thank'],
#  ['sure'],
#  ['double', 'size', 'divan', 'bed', 'frame'],
#  ['give', 'second', 'confirm', 'person', 'getting', 'item'],
#  ['anymore', 'question', 'need', 'ask'],
#  ['ok', 'im', 'waiting', 'reply'],
#  ['double', 'sized', 'divan', 'bed', 'frame', 'item'],
#  ['yes', 'lift', 'bed', 'frame', 'nd', 'floor', 'put', 'nd', 'floor', 'house'],
#  ['yes', 'correct'],
#  ['sure'],
#  ['flexible', 'time'],
#  ['thanks', 'help'],
#  ['large',
#   'chest',
#   'drawer',
#   'heavy',
#   'armchair',
#   'coffee',
#   'table',
#   'medium',
#   'size',
#   'lattice',
#   'wooden',
#   'box',
#   'folding',
#   'chair',
#   'large',
#   'framed',
#   'picture',
#   'coffee',
#   'table'],
#  ...]

# %% [markdown]
# ### Function to convert sentences/keywords into average vector representation

# %%
# Function to convert sentences/keywords into average vector representation
def sentence_to_avg_vector(text, model):
    words = word_tokenize(text)
    word_vectors = [model.wv[word] for word in words if word in model.wv]
    if not word_vectors:
        return np.zeros(model.vector_size)
    avg_vector = np.mean(word_vectors, axis=0)
    return avg_vector

# %% [markdown]
# ### Compute cosine similarity between sentence vectors and keyword vectors

# %%
# Compute cosine similarity between sentence vectors and keyword vectors
sentence_vectors = np.array([sentence_to_avg_vector(sentence, model) for sentence in corpus])
keyword_vectors = np.array([sentence_to_avg_vector(keyword, model) for keyword in corpus_key])

similarities = cosine_similarity(sentence_vectors, keyword_vectors)

# %%
similarities
# Out:
# array([[0.98825925, 0.99599196, 0.99789588, ..., 0.99876185, 0.99937653,
#         0.99882365],
#        [0.98912962, 0.99637837, 0.99840661, ..., 0.99907668, 0.99961359,
#         0.99897913],
#        [0.98825132, 0.9957669 , 0.99930954, ..., 0.99929131, 0.99888017,
#         0.99910931],
#        ...,
#        [0.98920216, 0.9953393 , 0.99704427, ..., 0.99812085, 0.99833649,
#         0.99778183],
#        [0.98944112, 0.99661063, 0.99844873, ..., 0.99904867, 0.99916445,
#         0.99911158],
#        [0.98834634, 0.99646892, 0.99797813, ..., 0.99883097, 0.9991258 ,
#         0.9987752 ]])

# %%
similarities.shape
# Out:
# (5879, 15)

# %% [markdown]
# ### Rank keywords based on their aggregated scores

# %%
# Aggregate the cosine similarities for each keyword across all sentences
keyword_scores = np.mean(similarities, axis=0)

# Rank keywords based on their aggregated scores
sorted_indices = np.argsort(keyword_scores)[::-1]
ranked_keywords = [(corpus_key[i], keyword_scores[i]) for i in sorted_indices]

# %% [markdown]
# ### Display the ranked keywords with their scores

# %%
# Display the ranked keywords with their scores
for rank, (keyword, score) in enumerate(ranked_keywords, start=1):
    print(f"Rank {rank}: Keyword = {keyword}, Score = {score:.4f}")
# Out:
# Rank 1: Keyword = stair, Score = 0.9421
# Rank 2: Keyword = storage, Score = 0.9421
# Rank 3: Keyword = garden, Score = 0.9420
# Rank 4: Keyword = street level, Score = 0.9418
# Rank 5: Keyword = front door, Score = 0.9418
# Rank 6: Keyword = delivery, Score = 0.9418
# Rank 7: Keyword = home, Score = 0.9413
# Rank 8: Keyword = level, Score = 0.9411
# Rank 9: Keyword = garage, Score = 0.9409
# Rank 10: Keyword = pickup, Score = 0.9399
# Rank 11: Keyword = bungalow, Score = 0.9395
# Rank 12: Keyword = right, Score = 0.9389
# Rank 13: Keyword = basement, Score = 0.9320
# Rank 14: Keyword = pavement, Score = 0.8693
# Rank 15: Keyword = downstair, Score = 0.0000

# %% [markdown]
# ### find sentences containg words present in keyword.csv

# %%
def find_sentences_with_similar_words(corpus, similar_words):
    """
    Search for sentences in the corpus that contain any of the similar words.

    Parameters:
    - corpus: List[str], the corpus of text (each element is a sentence or document).
    - similar_words: List[str], words similar to the search word.

    Returns:
    - Dict[str, List[str]], a dictionary where keys are similar words and values are lists of sentences containing those words.
    """
    # Initialize a dictionary to hold the results
    results = {word: [] for word in similar_words}
    
    # Iterate over the corpus to find sentences containing any of the similar words
    for sentence in corpus:
        for word in similar_words:
            if word in sentence.lower():  # Case-insensitive search
                results[word].append(sentence)
        
    counts = {word: len(sentences) for word, sentences in results.items()}
    
    data_for_df = [(word, "; ".join(sentences)) for word, sentences in results.items()]
 
    return results, counts , data_for_df


# Assuming 'model' is your trained Word2Vec model
#similar_words = [word for word, _ in model.wv.similar_by_word('delivery')]
similar_words=corpus_key
# Assuming 'corpus' is a list of sentences

# Find sentences containing similar words
sentences_with_similar_words , sentence_counts , data_for_df = find_sentences_with_similar_words(corpus, similar_words)

# Print the results
for word, sentences in sentences_with_similar_words.items():
    print(f"Sentences containing '{word}':")
    for sentence in sentences:
        print(f"- {sentence}")
    print()  # Blank line for readability

df_counts = pd.DataFrame(list(sentence_counts.items()), columns=['Word', 'Number of Sentences'])
df_sentences = pd.DataFrame(data_for_df, columns=['Word', 'Sentences'])
# Out:
# Sentences containing 'basement':
# - lift pick first floor flat delivery basement flat
# - basement flat basement flat lift
# - basement flat lift take stair one floor
# - basement stair climb
# - destination ground floor apartment moving duplex ground floor basement bedroom item basement stair
# - end basement
# - basement lift around steepish narrow stair
#
# Sentences containing 'bungalow':
# - bungalow
# - going bungalow
# - place gf dont know lady carpet bungalow
# - bungalow
# - bungalow property
# - ground floor flat bungalow back
# - ground floor flat bungalow
# - ground floor one garage item ground floor bungalow collect sofa house step going
# - first floor flat going bungalow
# - bungalow
# - live bungalow stair daughter garage flat outside house
# - need lift l said live bungalow every thing flat
# - bungalow stair
# - nd floor house straight internal stair main door destination bungalow
# - detached bungalow
# - bungalow
# - moving two bed flat bungalow
# - house collection bungalow
# - ground level house ground level bungalow
# - ground floor bungalow
# - ground floor bungalow
# - flat bungalow
# - bungalow
# - bungalow
# - floor bungalow lydiate speke bed upstairs
# - first floor bed lift couch bungalow floor
# - moving bungalow first floor
# - ground floor delivered bungalow
# - moving bungalow retirement flat lift parking n floor
# - coming bungalow dining room definitely arranged yet
#
# Sentences containing 'delivery':
# - door step delivery
# - hi rob need check delivery made quote showing different price one quoted checking vat help
# - industrial premise forklft forklift delivery end also
# - delivery location ground floor may require take upstairs house
# - wardrobe mostly dismantled ground floor delivery also ground floor
# - delivery home knighton
# - wanting peice suite delivery
# - ground floor delivery top floor modern block flat lift
# - lift pick first floor flat delivery basement flat
# - ground floor one item upstairs delivery address
# - pick delivery location main door ground floor
# - thanks selling worth person asking pay delivery
# - delivery location
# - lift delivery floor
# - ground floor house delivery ground floor house table disassembled leg
# - g ex would need storage unit chest drawer double bed mattress glass display unit tv tv unit small coffee table moved would need seater couch moved g r delivery ml yr
# - would st floor delivery address ground floor lift
# - following delivery l could take wardrobe wf approx min away door wardrobe
# - delivery adress ol pq
# - pick eg bd delivery eh dw
# - st floor lift delivery
# - ground floor pick nd floor delivery lift
# - hi actually thinking buying sofa someone local would pick delivery mine service still view sofa chair
# - come two piece would say lift delivery location said house
# - need discus pickup point person delivery point person get specific date time ok thanks
# - http thevanandman co uk chat pickup bt delivery bt city london area london query man van keyword device network adposition matchtype priceext headline expert removal london creative random london campaign id gclid btf cid jvdg
# - collection ground floor cottage delivery ground floor house step house long garden entrance house
# - ground floor pick first floor delivery lift
# - ground floor pick first floor delivery think lift
# - cash delivery
# - may trvel brighton bromley single way bromly delivery address
# - sorry mate way pick floor n lift n delivery th lift
# - picking g delivery g lr
# - collect b bed base delivery b mattress delivery b
# - ground floor pickup delivery
# - pick address colombia crescent wolverhampton wv gb delivery address flat moorland court melville road edgbaston b jr
# - ground floor garage delivery first floor lift
# - di delivery immediately pick min address
# - two seater sofa bed eh rw another stop pick long ladder box eh tw delivery eh hz
# - ground floor pick delivery item
# - delivery ground floor house
# - ground floor pick st floor delivery lift delivery close
# - baying tv stand argo delivery flat le mile
# - ground floor pick ground floor delivery
# - puck cv hw delivery cv jz
# - want refund taken day delivery package still delivered
# - okay good also okay accompany driver delivery address
# - two pick one lift delivery address
# - sorry mistake pick ground floor delivery rd floor lift
# - ground floor delivery nd floor lift
# - delivery second flor apartment
# - ground floor pick delivery
# - taking balance delivery
# - lift collection place lift delivery place
# - delivery maisonette flight stair nd floor lift needed
# - firdt floor lift delivery also first floor lift
# - much delivery
# - main door pick st floor delivery
# - delivery first floor lift though
# - ground floor pick st floor delivery c w lift
# - lift would needed collection delivery ground floor
# - lift lift needed ground floor collection delivery
# - ground delivery rd floor yes lift
# - depart address ground st delivery address ground second first floor lift
# - clicked link fill detail show delivery postcode stated
# - bt pt delivery pick ask
# - collection house delivery address flat th floor lift
# - delivery nd floor without lift assistance
# - delivery address rd floor
# - ground floor pickup ground floor delivery
# - ground floor uplift delivery two flight stair
# - pay delivery pickup
# - somebody internet problem confirm yesterday time delivery
# - sorry lost rob lift first floor delivery
# - ground floor pick first floor delivery
# - ground floor pick first floor delivery
# - ie upstairs delivery
# - sure need find would rd floor delivery
# - lift delivery address well
# - ground floor pickup floor delivery yes lift
# - ground floor delivery location
# - let check delivery first floor lift
# - unsure pick floor delivery would st floor flat
# - pickup location nd floor delivery ground floor
# - delivery location ground floor lift
# - lift pick point st floor delivery address flat
# - say next day delivery mid day
# - need confirm recipient delivery address
# - lift delivery location floor
# - st floor delivery rd floor go lift bed sofa
# - delivery place lift third floor see
# - floor delivery address
# - ground floor delivery
# - drive way delivery address
# - delivery point also need lift also ground floor
# - pick wakefield avenue delivery montrose terrace
# - ground floor lift needed delivery location storage unit
# - collection ground floor delivery togroundfloor
# - furniture kitchen bedroom item post office delivery van size small
# - downstairs room house help lifting end delivery first floor room
# - garage one location ground floor kitchen delivery location
# - hi rob really sorry newborn daughter tended delivery location floor house ground st converted attic lift
#
# Sentences containing 'downstair':
# - downstairs living room downstairs living room
# - two seater sofa downstairs van council tip meanwood l book slot
# - lift semi house item upstairs loft downstairs move item house needed
# - stored downstairs atm
# - could possibly get taken downstairs
# - maybe taken downstairs
# - st floor bedroom one flight stair lift happy move thing downstairs
# - upstairs room bed freezer kitchen downstairs
# - lift moving house house upstairs downstairs
# - lounge downstairs
# - downstairs living room
# - need wardrobe picked shop delivered also need old one taken downstairs
# - lift need carried downstairs
# - house tge stuff downstairs
# - would bring downstairs much would
# - say maisonette upstairs downstairs
# - bed needed brought upstairs rest downstairs
# - chest going stair hallway downstairs chest landing need furniture moving dropping
# - downstairs downstairs pick easy job
# - make sure item downstairs lift house
# - house downstairs
# - downstairs need pick bed
# - house try get wardrobe stuff downstairs
# - sofa downstairs
# - moving house item downstairs upstairs bedroom
# - first floor lift box tv downstairs
# - normal house furniture removed upstairs downstairs
# - downstairs lift
# - house lift item either downstairs upstairs
# - downstairs room house help lifting end delivery first floor room
# - think downstairs already
#
# Sentences containing 'front door':
# - lift get everything bottom taken front door
# - front door st floor
# - ground floor inside front door fine
# - stair coming front door
# - everything ready front door put van
# - door like average front door
# - side front door entry ground floor
# - main door flat step footpath front door
# - front door sorry
# - front door
# - outside front door floor
# - house upper bedroom front door new house going garage storage
# - front door ground floor
# - front door
# - top place want deliver building front door take flat
# - ground floor step front door
# - there lift back front door
# - need get rid double bed small chest draw old front door pick king size bed side table deliver l l hr
# - ist floor pick ups front door
# - double bed small box front door ready go
# - first floor flat going ground floor flat lift stair front door
# - first address front door house stair address going first floor lift
# - ground floor house via front door
# - pick front door drop thfloor lift suitable
# - ground floor front door
# - need lift front door directly garden
# - father died new year day none garbage sorted recycling since car hall need someone take front door nearest amenity center blackstaff way quote price service please
# - house front door simple job
# - front door willl others help getting uo
# - would collected front door
# - step front door
#
# Sentences containing 'garage':
# - garage shed
# - garage ground floor ground floor storage unit
# - item going garage ground floor
# - large box garage shelving
# - ground floor garage
# - ground floor one garage item ground floor bungalow collect sofa house step going
# - ground putting garage
# - half garage box
# - garage lift need
# - garage lift needed
# - single wardrobe go daughter garage
# - live bungalow stair daughter garage flat outside house
# - daughter garage outside house road flat
# - hello need move box app corner unit tv unit flat pack furniture chest drawer black bag ful clothes garage need go house shank hill first box flat pack furniture tv unit greenisland bag rest
# - house delivered garage front property lift stair involved
# - ground floor garage delivery first floor lift
# - pick upfrom garage deliver grounx floor flat
# - garage garden end stair lift
# - ground floor garage
# - house upper bedroom front door new house going garage storage
# - garage bed dismantled going ground floor flat
# - one wardrobe garage top floor flat give price
# - garage nd floor lift
# - normal ground floor garage drive way
# - garage
# - garage
# - ground floor garage
# - fridgefreezer helenvale flat tollcross rd old bus garage
# - garage
# - ground floor garage garage
# - side flat garage
# - item garage door
# - taken ground floor garage new build house
# - garage ground floor dropped ground floor
# - garage ground floor
# - garage
# - garage ground floor
# - garage one location ground floor kitchen delivery location
# - costco garage
# - size garage
# - got detail wrong sorry seller advised garage ground floor collection drop
#
# Sentences containing 'garden':
# - drop back garden shed
# - greenhouse garden
# - garden
# - plastic lightweight garden bench delivering coventry
# - side entry address ground floor garden coventry
# - moved garden entry effort ecpxtremily light
# - interested buying garden plastic wood affect bench perfect condition thought may b able sell job
# - dismantled garden shed approx flat load sise ftx
# - back garden b front garden b
# - lift involved garden garden
# - stable matt garden box slim metal locker three bin
# - quite packed box small furniture item freezer plant garden item
# - need cooker range collecting macclesfield delivering internally hg removing old range leaving front garden
# - collection ground floor cottage delivery ground floor house step house long garden entrance house
# - double bed sofa set seater seater seater dining table book case computer desk garden furniture small cabinet household item
# - king size bed mattress bed side table chest drawer mirror desk printer office chair bookcase shoe stand coat stand bathroom cabinet rug tv stand small coffee table seater sofa washing machine fridge freezer microwave dining table dining chair cd stand garden table garden chair parasol bbq chimnea golf bag golf trolley garden tool lawnmower linen basket strimmer small tv approx box
# - fridge garden bench garden wood burned burner
# - ground floor garden
# - ground floor garden
# - flatpack king size bed king size mattress standard size box suitcase small medium large backpack dining room chair fold dining room table coffee table nest table curved chair garden bench office chair flat pack screen flat pack study desk x medium size plastic storage box wide bookcase narrow ikea bookcase narrow cupboard carpet rug narrow drawer set seater sofa coat stand
# - garage garden end stair lift
# - garden floor
# - garden floor
# - garden
# - garden
# - ground floor house approx step front garden path outside house
# - gonna dismantle approx kg going front garden
# - garden bench
# - garden
# - id like two drop possible first one b sn second postcode b steel road sure exact ending thats road nearby chest freezer two garden planter go b sn mud kitchen around x x table around x x b
# - garden planter around x cm x cm
# - seater sofa crner sofa king size bed chest drawer large crate household good crockery cutlery etc egg chair garden furniture
# - garden
# - lightweight modern sofabed chest drawer medium lightweight sideboard small light chair lightweight modern small kitchen chair standard lamp tv small round wire basket side table small console table microwave pan crockery food toaster kettle bedding laundry basket basket clothes towel book magazine tool medium light metal box garden tool like spade fork rake small picture wall mirror medium size plant small drawer bathroom cabinet slightly bigger drawer small cabinet
# - ground ground floor garden
# - back garden floor garden
# - floor straight garden
# - garden furniture table chair
# - ground floor garden
# - ground floor garden
# - chair front garden
# - garden fence panel b house
# - need lift front door directly garden
# - straight store back garden
# - garden
# - around box tv two small tv bike lawn mower garden tool chair hostess trolley
# - two seater sofa three seater sofa double bed single bed desk triple wardrobe wardrobe chest drawer large box television stand television garden box garden swing washing machine cooker book stand flatpack wardrobe
# - small list garden furniture wendy house
# - garden
# - garden content presently stored container nothing huge heavy
# - ground floor garden
#
# Sentences containing 'home':
# - bought item yet need check still available home
# - know never husband friend take furniture home van
# - seater sofa home daughter mile
# - delivery home knighton
# - wardrobe pick ikea sheffield home leicester
# - destination lift home flat stair
# - would need specific time would confirm later care home care home job goalpost moving
# - would taken broomhill psrk flat nursing home ithe furniture understand left outside back building shall check exactly say reception
# - mean much cost totally dismantle furniture move new home assembly furniture
# - whichever cost extra home anyway
# - home furniture
# - non lift would delivered home ground floor
# - specific get home till time would pick gyle
# - home
# - moving home large number box mostly book piece furniture shelf table chest drawer chair
# - working home
# - sure ground floor home
# - ground floor ground floor sure nursing home lift
# - specific time going get back check nursing home see best
# - need move furniture two address currently living home two address pick furniture possible first address briar street l rb x ft vivarium x ferret cage second address hutchinson walk l jw x sofa seater x double bed mattress pre disassembled x large tv stand x fridge freezer x washing machine
# - pick stationary bike gym bring home
# - collection home flat first floor lift
#
# Sentences containing 'level':
# - one level
# - ground level delivered ground level
# - ground level
# - ground level
# - street level going bunglow
# - street level
# - street level
# - street level
# - street level
# - lift needed groung level pick drop
# - ground level lift
# - put stuff bottom stair level new flat
# - one level
# - ground floor six step carry package street level
# - store self ground level cooker curry store forestside delivered maymount st ground level kitchen u price pls
# - dismantling assembly large furniture item needed nformation property item moved living room x seat sofa x seat sofa x coffee table x upright piano x shelving unit item moved kitchen dining x dining table x chair x tv bench x cupboard x tv monitor item moved bedroom x medium box x chest drawer x chest drawer x bed storage x mattress item moved x bike pick address information type property house highest level property nd floor drop address type property house highest level property st floor
# - pick piano cupboard ground floor want detail floor pick ground plus level drop ground plus level
# - storageon ground level
# - ground level
# - house house street level
# - house block top floor level
# - main door house lift street level
# - ground level house ground level bungalow
# - pick first floor drop ground level
# - sure think ground level
#
# Sentences containing 'pavement':
# - drop pavement
# - outside house ground floor recipient pavement outside would probably
# - ground floor pavement outside
#
# Sentences containing 'pickup':
# - men pickup drop stuff
# - pickup eh sq going eh nb minute drive
# - house need pickup chipstead road b drop wendover road b
# - need discus pickup point person delivery point person get specific date time ok thanks
# - http thevanandman co uk chat pickup bt delivery bt city london area london query man van keyword device network adposition matchtype priceext headline expert removal london creative random london campaign id gclid btf cid jvdg
# - ground floor pickup delivery
# - close entry pickup could dropped close entry destination end
# - fine however machine paid pickup address l ap first pay upfront giving machine please
# - ground floor pickup nd floor drop lift
# - sure item waiting street pickup
# - ground floor pickup outside house actually
# - pickup
# - ground floor pickup ground floor delivery
# - pay delivery pickup
# - ground floor pickup floor delivery yes lift
# - pickup location nd floor delivery ground floor
# - coming main door dont know main door pickup
#
# Sentences containing 'right':
# - right come back quote
# - right back min
# - set shelf dismantled hard say probably four unist approx cm x cm x cm ten upright cm thick metre high cm deep shelf approx cm long x cm deep
# - yes one upright piano height cm ground floor ground floor
# - may trvel brighton bromley single way bromly delivery address
# - mean convenient get lift brighton bromley bromley yet may take lot time road
# - upright piano
# - right ok get back ok
# - need lift right back door
# - yes right
# - dismantling assembly large furniture item needed nformation property item moved living room x seat sofa x seat sofa x coffee table x upright piano x shelving unit item moved kitchen dining x dining table x chair x tv bench x cupboard x tv monitor item moved bedroom x medium box x chest drawer x chest drawer x bed storage x mattress item moved x bike pick address information type property house highest level property nd floor drop address type property house highest level property st floor
# - sound right
# - book take payment right away day
# - ground floor parking access right outside door parking need pre arranged security guy
# - sorry checking live need anything right
# - son moving possession leicester brighton consist approximately cardboard box range bag mattress bit piece
# - thank info hope get right bid book regard pauline
# - right getting quote thanks
# - upright piano
# - know thats right postcode new place ruchill
# - hi yes right
# - item upright piano
# - also bidet hemel hempstead brighton
# - right
#
# Sentences containing 'stair':
# - first floor lift wide staircase
# - hi rob three seater sofa two chair nest small table chest drawer l l two seat sofa l aw house l stair lift thanks
# - downstairs living room downstairs living room
# - ground floor flat stair leading flat
# - ground floor stair
# - one flight stair
# - two seater sofa downstairs van council tip meanwood l book slot
# - upstairs bedroom first floor lift remove leg try chop bit
# - first drop first floor apart stair
# - stair first floor
# - bed house bring everything upstairs stair removal people
# - upstairs could bring
# - delivery location ground floor may require take upstairs house
# - secod floor lift stair
# - ground floor one item upstairs delivery address
# - stair also back gate completely flat
# - lift nd floor flight stair
# - lift semi house item upstairs loft downstairs move item house needed
# - stair
# - stair
# - house converted flat shall stair flat
# - stair lift
# - nope house house stair lift
# - house main door street upstairs flight stair bedroom
# - main door main door carpet upstairs please bedroom
# - stored downstairs atm
# - lift stair
# - upstairs house
# - stair
# - stair
# - need carried stair require two peopls people
# - upstairs bed room stair semi detatched house
# - could possibly get taken downstairs
# - maybe taken downstairs
# - stair door
# - middle stair
# - st floor bedroom one flight stair lift happy move thing downstairs
# - bedroom shared house normal amount stair
# - st floor upstairs
# - first floor stair going house stair
# - bed wardrobe upstairs everything else stair
# - chester draw upstairs well
# - upstairs room bed freezer kitchen downstairs
# - house living room stair
# - would first floor however stair leading house aswell
# - well instead taking upstairs drop ground floor got lift anything upstairs
# - lift moving house house upstairs downstairs
# - lounge downstairs
# - two flight stair
# - ground floor stair
# - drop set stair happy
# - stair pick drop
# - destination lift home flat stair
# - pick point ground floor drop point st floor stair
# - downstairs living room
# - house bottom floor dropped house get stair dad
# - need picked flat maybe stair n stay bottom flat stair
# - house upstairs bed wardrobe lift
# - need delivered house sure lifting stair required
# - put stuff bottom stair level new flat
# - stair coming front door
# - live bungalow stair daughter garage flat outside house
# - nd floor small set stair doorway van
# - need wardrobe picked shop delivered also need old one taken downstairs
# - lift need carried downstairs
# - one house donegall road one flight stair
# - need lift round stair
# - upstairs lift
# - upstairs lift
# - lift house painting upstairs flight
# - nope stair
# - bungalow stair
# - nd floor house straight internal stair main door destination bungalow
# - house tge stuff downstairs
# - told contacted email mover dropping sofa knocking stair received information
# - top close takin ground stair
# - st floor maisonette buts massive set stair
# - st floor semi detached house lift well bed would need taken upstairs drawer chair table
# - upstairs house
# - st floor storage lift lounge house stair
# - apartment one set stair help
# - l le l sq stair direct entry
# - house delivered garage front property lift stair involved
# - open flat stair block
# - house upstairs
# - would bring downstairs much would
# - spittal entrance front road back car park lot stair flat lift
# - ground floor maisonette com back way use stair
# - say maisonette upstairs downstairs
# - st floor lift set stair
# - bed needed brought upstairs rest downstairs
# - seater sofa dawn one flight stair seater bedroom house
# - upstairs bedroom
# - seater need arm taken get dawn stair outside taken away
# - sorry rob bit miked chair purchased haditat shop based sainsbury graig lieth stair
# - garage garden end stair lift
# - house stair lift
# - house stair lift
# - stair main door
# - manor house huge wide staircase
# - yes would fit going upstairs need dispose take mine
# - chest going stair hallway downstairs chest landing need furniture moving dropping
# - back way stair
# - ground floor house item transported back stair
# - bedroom flight stair
# - sorry connecting cooker removing old one taking stair outside lift
# - old fashioned tv taken stair
# - floor stair lift
# - delivery maisonette flight stair nd floor lift needed
# - basement flat lift take stair one floor
# - basement stair climb
# - ground floor stair outside house
# - flat shop stair bit steep managed get get stuff
# - upper cottage flat stair total
# - st floor going st floor stair
# - downstairs downstairs pick easy job
# - st floor flight stair lift
# - second floor tenement flat quite steep hill lift stair
# - one flight stair wv p ground floor property wv
# - main door house step bed drawer taken upstairs inside house
# - location stair leading house main door probly
# - first floor bedroom stair lift terraced house
# - ground floor well take everything upstairs
# - lift house unit upstairs
# - ground floor main door flat moving st floor main door flat accessed via flight outside stair
# - storage container stair
# - make sure item downstairs lift house
# - pick girdleness road torry door stair dropping c wellington road torry st floor flat
# - fist floor second floor lift stair
# - ground floor ground floor stair
# - lift first floor set stair come main building
# - tenement one flight stair
# - two flight go stair
# - house staying stair stair need climb
# - ground floor stay groud floor stair going flat dont lift
# - thankyou still shopping around seems quite expensive wardrobe minute journey u leave bottom stair cheaper
# - destination ground floor apartment moving duplex ground floor basement bedroom item basement stair
# - ground floor uplift delivery two flight stair
# - round floor take upstairs
# - ground floor stair
# - house stair
# - g flight stair g stair g flight stair
# - g stair
# - one flight like upstairs house taking note size van half ton van name morag pirrie partner collection point john machin
# - ground floor fine husband carry upstairs
# - house downstairs
# - bottom floor straight door main door stair
# - main door set stair bedroom stuff straight kitchen sitting room
# - one flight stair lift
# - set stair st floor help lift
# - ie upstairs delivery
# - st floor small lift stairwell next
# - house ground floor stair involved
# - partner carry stair
# - ground floor block external stair
# - downstairs need pick bed
# - floor bungalow lydiate speke bed upstairs
# - upstairs lift leave outside door bottom stair
# - one set stair step
# - upstairs house
# - st floor lift upstair villa
# - getting picked hillswick crescent milton house stair gran house outside
# - sorry would taken high rise flat castlebay drive flat milton lift go would stair walk get flat
# - flat shop one set stair jo lift
# - first floor flat going ground floor flat lift stair front door
# - first address front door house stair address going first floor lift
# - ground stair
# - item going stair house
# - th one set outside stair maisonette first floor
# - stair
# - pick ground floor stair drop st floor
# - first floor flight stair
# - house try get wardrobe stuff downstairs
# - well moving new house bedroom stuff go upstairs
# - sofa downstairs
# - basement lift around steepish narrow stair
# - moving house item downstairs upstairs bedroom
# - first floor upstairs house lift
# - first floor flat stair lift floor
# - st floor stair tenement
# - first floor lift box tv downstairs
# - normal house furniture removed upstairs downstairs
# - downstairs lift
# - bed upstairs lift
# - house lift item either downstairs upstairs
# - upstairs first floor
# - stair house
# - upstairs house lift
# - inch television going block three floor stair
# - th floor lift go th there wee set stair
# - first floor life stair
# - lift item picked st floor tenement spiral staircase taken second floor flat end tenement spiral case
# - downstairs room house help lifting end delivery first floor room
# - st floor block communal flat lift flight stair
# - small set stair lift
# - also stair pick hp
# - side flat brother help lift one flight stair
# - first stayed stair
# - floor upstairs
# - think downstairs already
# - stair pick
#
# Sentences containing 'storage':
# - business move large printer requiring four people lift shelving storage unit
# - paper drill mainly box storage unit desk
# - x bedroom apartment furniture item living room bedroom moving stuff storage serviced apartment block
# - item medium storage box another storage container
# - garage ground floor ground floor storage unit
# - storage floor lift r first floor like bed near darnlay b q
# - g ex would need storage unit chest drawer double bed mattress glass display unit tv tv unit small coffee table moved would need seater couch moved g r delivery ml yr
# - pick house going storage unit ground floor
# - storage unit trolley need
# - needing furniture moved old ptoperty g sp new property g ap including aditional furniture delivered storage unit g oty item moved old new property include seater sofa single bed king size bed set bedroom drawer bedside table coffee table side table
# - storage unit take flat take want picked drop
# - storage unit lift trolley thing carry item nd floor
# - approx box kitchen cabinet metal pull file cabinet first floor storage ground floor
# - remove one armchair storage house
# - st floor storage lift lounge house stair
# - fridge freezer seater chesterfield sofa tv stand sideboard x wooden armchair coffee table small fold dining table king size bed dismantled storage chest free standing clothes rail x chest drawer bedside unit daybed computer desk exercise bike
# - going storage locker placed outside carpark space
# - flatpack king size bed king size mattress standard size box suitcase small medium large backpack dining room chair fold dining room table coffee table nest table curved chair garden bench office chair flat pack screen flat pack study desk x medium size plastic storage box wide bookcase narrow ikea bookcase narrow cupboard carpet rug narrow drawer set seater sofa coat stand
# - dont know exact yet bough item lady sofa storage unit ashton lyne
# - change know time lady storage unit
# - ground floor residential ground floor storage centre
# - dismantling assembly large furniture item needed nformation property item moved living room x seat sofa x seat sofa x coffee table x upright piano x shelving unit item moved kitchen dining x dining table x chair x tv bench x cupboard x tv monitor item moved bedroom x medium box x chest drawer x chest drawer x bed storage x mattress item moved x bike pick address information type property house highest level property nd floor drop address type property house highest level property st floor
# - one king size bed without storage
# - entirely certain approximately small box medium box large box rucksack large suitcase small suitcase bedside table tv computer monitor large blanket bag storage unit metre squared
# - moving bed house storage seater piece suite double divan bed mattress metal double bed frame mattress wardrobe bed side table single bed
# - storageon ground level
# - might put storage unit manchester
# - house upper bedroom front door new house going garage storage
# - squirell storage tyburn rd erdington chest freezer high street king heath ground floor
# - rd floor large lift big yellow storage
# - need take mattress storage unit bring another back
# - one tall storage locker one chest drawer one book shelf
# - wardrobe desk shelving unit cube storage unit
# - small double divan bed mattress suitcase bag plastic storage draw
# - approximately medium box tv small storage unit black bag rucksack small box
# - storage container stair
# - sure taken self storage location booked yet
# - wooden blanket chest tv stand bed size cabinet medium storage box
# - xtwo seater sofa king size bed single bed fridge freezer tumble dryer storage side unit
# - need tonne luton van whic long stuff storage required
# - hi sorry first post code wrong b dt ground floor storage unit
# - washing machine fridge freezer small chest freezer microwave seater leather corner suite come apart piece double bed already dismantled storage container content glass table small coffee table tv boxed chest drawer pic small tv stand small glass tv stand set ladder last tub paint small cupboard mike
# - storage unit lift
# - need collecting storage unit flat
# - sure storage facility however sure easily accessible lift etc
# - called big yellow self storage liverpool edge lane
# - edinburgh big yellow storage lift
# - storage unit rd floor
# - ground floor lift needed delivery location storage unit
# - three seater sofa double bed mattress two ottoman storage box
#
# Sentences containing 'street level':
# - street level going bunglow
# - street level
# - street level
# - street level
# - street level
# - ground floor six step carry package street level
# - house house street level
# - main door house lift street level

# %% [markdown]
# ### count no of sentences

# %%
df_counts_sorted = df_counts.sort_values(by='Number of Sentences', ascending=False)
df_counts_sorted
# Out:
#             Word  Number of Sentences
# 12         stair                  201
# 2       delivery                  102
# 6         garden                   51
# 13       storage                   50
# 5         garage                   41
# 3      downstair                   31
# 4     front door                   31
# 1       bungalow                   30
# 8          level                   25
# 11         right                   24
# 7           home                   22
# 10        pickup                   17
# 14  street level                    8
# 0       basement                    7
# 9       pavement                    3

# %% [markdown]
# ### Function to count occurrences of each keyword or phrase in the corpus

# %%
# Function to count occurrences of each keyword or phrase in the corpus
def count_keyword_occurrences(corpus, keywords):
    # Convert the entire corpus into a single string for easier searching
    corpus_text = ' '.join(corpus).lower()
    
    # Initialize a dictionary to hold the count of occurrences for each keyword
    keyword_occurrences = {}
    
    # Loop through each keyword to find and count its occurrences in the corpus text
    for keyword in keywords:
        # Normalize keyword to ensure consistent matching
        normalized_keyword = keyword.lower()
        # Count occurrences of the keyword in the corpus text
        count = corpus_text.count(normalized_keyword)
        # Store the count in the dictionary
        keyword_occurrences[keyword] = count
    
    return keyword_occurrences

# Assuming corpus and corpus_key are defined as before
# Normalize keywords since we're dealing with exact matches
keywords = [keyword.lower() for keyword in corpus_key]

# Count occurrences of each keyword or phrase in the corpus
keyword_occurrences = count_keyword_occurrences(corpus, keywords)

# keyword_occurrences now contains the count of each keyword or phrase present in the corpus

# %% [markdown]
# ### keyword_occurrences_sorted_dict now contains the sorted occurrences in decreasing order

# %%
# Assuming keyword_occurrences is the dictionary with keyword counts
keyword_occurrences_sorted = sorted(keyword_occurrences.items(), key=lambda x: x[1], reverse=True)

# Convert sorted list of tuples back to a dictionary if you prefer dictionary format
keyword_occurrences_sorted_dict = dict(keyword_occurrences_sorted)

# keyword_occurrences_sorted_dict now contains the sorted occurrences in decreasing order

# %%
keyword_occurrences_sorted_dict
# Out:
# {'stair': 224,
#  'delivery': 104,
#  'garden': 58,
#  'storage': 51,
#  'garage': 42,
#  'downstair': 33,
#  'front door': 31,
#  'bungalow': 30,
#  'level': 30,
#  'right': 24,
#  'home': 23,
#  'pickup': 17,
#  'basement': 9,
#  'street level': 8,
#  'pavement': 3}

# %% [markdown]
# ## Phase 2: Analysis with Duplicate Removal
#
# ### Removing Duplicate Sentences
#
# - **Objective:** Examine the impact of duplicate sentences on keyword significance.
# - **Method:** Identify and eliminate duplicate sentences from the dataset.
#
# ### Spelling Correction
#
# - **Objective:** Address spelling variations that may affect keyword detection and frequency counts.
# - **Method:** Apply a spelling checker to correct misspellings within the dataset.
#
# ### Re-evaluation of Keyword Significance

# %%
df = df.drop_duplicates(keep='first')
df = df.reset_index(drop=True)

# %%
# Preprocess sentences in the corpus

corpus = []
lemmatizer = WordNetLemmatizer()
for i in range(len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['message'][i])
    review = review.lower().split()
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# Preprocess keywords
corpus_key = []
for i in range(len(df_key)):
    review = re.sub('[^a-zA-Z0-9]', ' ', df_key['keyword'][i])
    review = review.lower().split()
    review = [lemmatizer.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus_key.append(review)

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

def correct_spelling(text):
    corrected_text = []
    for word in text.split():
        corrected_word = spell.correction(word)
        # Safeguard against None values
        if corrected_word is None:
            corrected_word = word  # Use the original word if correction is None
        corrected_text.append(corrected_word)
    return ' '.join(corrected_text)

# Assuming your corpus and corpus_key are correctly formatted as lists of strings:
corrected_corpus = [correct_spelling(sentence) for sentence in corpus]
corrected_corpus_key = [correct_spelling(keyword) for keyword in corpus_key]

# %%
corpus=corrected_corpus
corpus_key=corrected_corpus_key

# %%
# Tokenize sentences for Word2Vec training
tokens = [simple_preprocess(sentence) for sentence in corpus]

# Train Word2Vec model
model = Word2Vec(sentences=tokens, vector_size=100, window=5, min_count=1, workers=4)

# Function to convert sentences/keywords into average vector representation
def sentence_to_avg_vector(text, model):
    words = word_tokenize(text)
    word_vectors = [model.wv[word] for word in words if word in model.wv]
    if not word_vectors:
        return np.zeros(model.vector_size)
    avg_vector = np.mean(word_vectors, axis=0)
    return avg_vector

# Compute cosine similarity between sentence vectors and keyword vectors
sentence_vectors = np.array([sentence_to_avg_vector(sentence, model) for sentence in corpus])
keyword_vectors = np.array([sentence_to_avg_vector(keyword, model) for keyword in corpus_key])

similarities = cosine_similarity(sentence_vectors, keyword_vectors)

# %%
similarities
# Out:
# array([[0.98685736, 0.99604942, 0.99837576, ..., 0.99827162, 0.99923506,
#         0.99858844],
#        [0.98757117, 0.99624609, 0.99855956, ..., 0.99871103, 0.99948887,
#         0.99889821],
#        [0.98715331, 0.99662622, 0.99934995, ..., 0.99930452, 0.99919228,
#         0.99885465],
#        ...,
#        [0.98784638, 0.99636964, 0.99847949, ..., 0.99904741, 0.99915728,
#         0.99894208],
#        [0.98838416, 0.9962823 , 0.99859464, ..., 0.99899403, 0.99918126,
#         0.9990199 ],
#        [0.98781515, 0.99549555, 0.99827015, ..., 0.99845103, 0.99929779,
#         0.99877143]])

# %%
# Aggregate the cosine similarities for each keyword across all sentences
keyword_scores = np.mean(similarities, axis=0)

# Rank keywords based on their aggregated scores
sorted_indices = np.argsort(keyword_scores)[::-1]
ranked_keywords = [(corpus_key[i], keyword_scores[i]) for i in sorted_indices]

# Display the ranked keywords with their scores
for rank, (keyword, score) in enumerate(ranked_keywords, start=1):
    print(f"Rank {rank}: Keyword = {keyword}, Score = {score:.4f}")
# Out:
# Rank 1: Keyword = storage, Score = 0.9629
# Rank 2: Keyword = garden, Score = 0.9629
# Rank 3: Keyword = stair, Score = 0.9628
# Rank 4: Keyword = front door, Score = 0.9628
# Rank 5: Keyword = street level, Score = 0.9627
# Rank 6: Keyword = delivery, Score = 0.9626
# Rank 7: Keyword = home, Score = 0.9623
# Rank 8: Keyword = downstairs, Score = 0.9620
# Rank 9: Keyword = level, Score = 0.9618
# Rank 10: Keyword = garage, Score = 0.9608
# Rank 11: Keyword = bungalow, Score = 0.9603
# Rank 12: Keyword = pickup, Score = 0.9599
# Rank 13: Keyword = right, Score = 0.9587
# Rank 14: Keyword = basement, Score = 0.9518
# Rank 15: Keyword = pavement, Score = 0.7891

# %%
def find_sentences_with_similar_words(corpus, similar_words):
    """
    Search for sentences in the corpus that contain any of the similar words.

    Parameters:
    - corpus: List[str], the corpus of text (each element is a sentence or document).
    - similar_words: List[str], words similar to the search word.

    Returns:
    - Dict[str, List[str]], a dictionary where keys are similar words and values are lists of sentences containing those words.
    """
    # Initialize a dictionary to hold the results
    results = {word: [] for word in similar_words}
    
    # Iterate over the corpus to find sentences containing any of the similar words
    for sentence in corpus:
        for word in similar_words:
            if word in sentence.lower():  # Case-insensitive search
                results[word].append(sentence)
        
    counts = {word: len(sentences) for word, sentences in results.items()}
    
    data_for_df = [(word, "; ".join(sentences)) for word, sentences in results.items()]
 
    return results, counts , data_for_df


# Assuming 'model' is your trained Word2Vec model
#similar_words = [word for word, _ in model.wv.similar_by_word('delivery')]
similar_words=corpus_key
# Assuming 'corpus' is a list of sentences

# Find sentences containing similar words
sentences_with_similar_words , sentence_counts , data_for_df = find_sentences_with_similar_words(corpus, similar_words)

# Print the results
for word, sentences in sentences_with_similar_words.items():
    print(f"Sentences containing '{word}':")
    for sentence in sentences:
        print(f"- {sentence}")
    print()  # Blank line for readability

df_counts = pd.DataFrame(list(sentence_counts.items()), columns=['Word', 'Number of Sentences'])
df_sentences = pd.DataFrame(data_for_df, columns=['Word', 'Sentences'])
# Out:
# Sentences containing 'basement':
# - lift pick first floor flat delivery basement flat
# - basement flat basement flat lift
# - basement flat lift take stair one floor
# - basement stair climb
# - destination ground floor apartment moving duplex ground floor basement bedroom item basement stair
# - end basement
# - basement lift around sheepish narrow stair
#
# Sentences containing 'bungalow':
# - bungalow
# - first floor lift bungalow
# - street level going bungalow
# - going bungalow
# - place of don't know lady carpet bungalow
# - bungalow
# - bungalow property
# - ground floor flat bungalow back
# - ground floor flat bungalow
# - ground floor one garage item ground floor bungalow collect sofa house step going
# - first floor flat going bungalow
# - live bungalow stair daughter garage flat outside house
# - need lift l said live bungalow every thing flat
# - bungalow stair
# - and floor house straight internal stair main door destination bungalow
# - detached bungalow
# - bungalow
# - moving two bed flat bungalow
# - house collection bungalow
# - ground level house ground level bungalow
# - ground floor bungalow
# - ground floor bungalow
# - flat bungalow
# - bungalow
# - floor bungalow radiate spoke bed upstairs
# - first floor bed lift couch bungalow floor
# - moving bungalow first floor
# - ground floor delivered bungalow
# - moving bungalow retirement flat lift parking n floor
# - coming bungalow dining room definitely arranged yet
#
# Sentences containing 'delivery':
# - door step delivery
# - hi rob need check delivery made quote showing different price one quoted checking vat help
# - industrial premise forklift forklift delivery end also
# - delivery location ground floor may require take upstairs house
# - wardrobe mostly dismantled ground floor delivery also ground floor
# - delivery home knight
# - wanting piece suite delivery
# - ground floor delivery top floor modern block flat lift
# - lift pick first floor flat delivery basement flat
# - ground floor one item upstairs delivery address
# - pick delivery location main door ground floor
# - thanks selling worth person asking pay delivery
# - delivery location
# - lift delivery floor
# - ground floor house delivery ground floor house table disassembled leg
# - g ex would need storage unit chest drawer double bed mattress glass display unit to to unit small coffee table moved would need sweater couch moved g r delivery my or
# - would it floor delivery address ground floor lift
# - following delivery l could take wardrobe of approve in away door wardrobe
# - delivery dress of pa
# - pick beg be delivery eh do
# - it floor lift delivery
# - ground floor pick and floor delivery lift
# - hi actually thinking buying sofa someone local would pick delivery mine service still view sofa chair
# - come two piece would say lift delivery location said house
# - need discus pickup point person delivery point person get specific date time of thanks
# - help thevanandman to up chat pickup it delivery it city onion area onion query man van keyword device network apposition matchtype priciest headline expert removal onion creative random onion campaign id gelid to did judge
# - collection ground floor cottage delivery ground floor house step house long garden entrance house
# - ground floor pick first floor delivery lift
# - ground floor pick first floor delivery think lift
# - cash delivery
# - may travel brighten trolley single way brolly delivery address
# - sorry mate way pick floor n lift n delivery the lift
# - picking g delivery g or
# - collect b bed base delivery b mattress delivery b
# - ground floor pickup delivery
# - pick address colombia crescent wolverhampton we go delivery address flat moorland court melville road edgbaston b or
# - ground floor garage delivery first floor lift
# - i delivery immediately pick in address
# - two sweater sofa bed eh re another stop pick long ladder box eh to delivery eh he
# - ground floor pick delivery item
# - delivery ground floor house
# - ground floor pick it floor delivery lift delivery close
# - baying to stand ago delivery flat we mile
# - ground floor pick ground floor delivery
# - puck c he delivery c ja
# - want refund taken day delivery package still delivered
# - okay good also okay accompany driver delivery address
# - two pick one lift delivery address
# - sorry mistake pick ground floor delivery red floor lift
# - ground floor delivery and floor lift
# - delivery second for apartment
# - ground floor pick delivery
# - taking balance delivery
# - lift collection place lift delivery place
# - delivery maisonette flight stair and floor lift needed
# - first floor lift delivery also first floor lift
# - much delivery
# - main door pick it floor delivery
# - delivery first floor lift though
# - ground floor pick it floor delivery c w lift
# - lift would needed collection delivery ground floor
# - lift lift needed ground floor collection delivery
# - ground delivery red floor yes lift
# - depart address ground it delivery address ground second first floor lift
# - clicked link fill detail show delivery postcode stated
# - it it delivery pick ask
# - collection house delivery address flat the floor lift
# - delivery and floor without lift assistance
# - delivery address red floor
# - ground floor pickup ground floor delivery
# - ground floor uplift delivery two flight stair
# - pay delivery pickup
# - somebody internet problem confirm yesterday time delivery
# - sorry lost rob lift first floor delivery
# - ground floor pick first floor delivery
# - ground floor pick first floor delivery
# - i upstairs delivery
# - sure need find would red floor delivery
# - lift delivery address well
# - ground floor pickup floor delivery yes lift
# - ground floor delivery location
# - let check delivery first floor lift
# - unsure pick floor delivery would it floor flat
# - pickup location and floor delivery ground floor
# - delivery location ground floor lift
# - lift pick point it floor delivery address flat
# - say next day delivery mid day
# - need confirm recipient delivery address
# - lift delivery location floor
# - it floor delivery red floor go lift bed sofa
# - delivery place lift third floor see
# - floor delivery address
# - ground floor delivery
# - drive way delivery address
# - delivery point also need lift also ground floor
# - pick wakefield avenue delivery mongoose terrace
# - ground floor lift needed delivery location storage unit
# - collection ground floor delivery togroundfloor
# - furniture kitchen bedroom item post office delivery van size small
# - downstairs room house help lifting end delivery first floor room
# - garage one location ground floor kitchen delivery location
# - hi rob really sorry newborn daughter tended delivery location floor house ground it converted attic lift
#
# Sentences containing 'downstairs':
# - downstairs living room downstairs living room
# - two sweater sofa downstairs van council tip manhood l book slot
# - lift semi house item upstairs loft downstairs move item house needed
# - stored downstairs at
# - could possibly get taken downstairs
# - maybe taken downstairs
# - it floor bedroom one flight stair lift happy move thing downstairs
# - upstairs room bed freezer kitchen downstairs
# - lift moving house house upstairs downstairs
# - lounge downstairs
# - downstairs living room
# - need wardrobe picked shop delivered also need old one taken downstairs
# - lift need carried downstairs
# - house the stuff downstairs
# - would bring downstairs much would
# - say maisonette upstairs downstairs
# - bed needed brought upstairs rest downstairs
# - chest going stair hallway downstairs chest landing need furniture moving dropping
# - downstairs downstairs pick easy job
# - make sure item downstairs lift house
# - house downstairs
# - downstairs need pick bed
# - house try get wardrobe stuff downstairs
# - sofa downstairs
# - moving house item downstairs upstairs bedroom
# - first floor lift box to downstairs
# - normal house furniture removed upstairs downstairs
# - downstairs lift
# - house lift item either downstairs upstairs
# - downstairs room house help lifting end delivery first floor room
# - think downstairs already
#
# Sentences containing 'front door':
# - lift get everything bottom taken front door
# - front door it floor
# - ground floor inside front door fine
# - stair coming front door
# - everything ready front door put van
# - door like average front door
# - side front door entry ground floor
# - main door flat step footpath front door
# - front door sorry
# - front door
# - outside front door floor
# - house upper bedroom front door new house going garage storage
# - front door ground floor
# - front door
# - top place want deliver building front door take flat
# - ground floor step front door
# - there lift back front door
# - need get rid double bed small chest draw old front door pick king size bed side table deliver l l he
# - is floor pick ups front door
# - double bed small box front door ready go
# - first floor flat going ground floor flat lift stair front door
# - first address front door house stair address going first floor lift
# - ground floor house via front door
# - pick front door drop floor lift suitable
# - ground floor front door
# - need lift front door directly garden
# - father died new year day none garbage sorted recycling since car hall need someone take front door nearest amenity center blackstaff way quote price service please
# - house front door simple job
# - front door will others help getting to
# - would collected front door
# - step front door
#
# Sentences containing 'garage':
# - garage shed
# - garage ground floor ground floor storage unit
# - item going garage ground floor
# - large box garage shelving
# - ground floor garage
# - ground floor one garage item ground floor bungalow collect sofa house step going
# - ground putting garage
# - half garage box
# - garage lift need
# - garage lift needed
# - single wardrobe go daughter garage
# - live bungalow stair daughter garage flat outside house
# - daughter garage outside house road flat
# - hello need move box ape corner unit to unit flat pack furniture chest drawer black bag full clothes garage need go house shank hill first box flat pack furniture to unit greensand bag rest
# - house delivered garage front property lift stair involved
# - ground floor garage delivery first floor lift
# - pick from garage deliver ground floor flat
# - garage garden end stair lift
# - ground floor garage
# - house upper bedroom front door new house going garage storage
# - garage bed dismantled going ground floor flat
# - one wardrobe garage top floor flat give price
# - garage and floor lift
# - normal ground floor garage drive way
# - garage
# - garage
# - ground floor garage
# - fridgefreezer helenvale flat tollcross red old bus garage
# - garage
# - ground floor garage garage
# - side flat garage
# - item garage door
# - taken ground floor garage new build house
# - garage ground floor dropped ground floor
# - garage ground floor
# - garage
# - garage ground floor
# - garage one location ground floor kitchen delivery location
# - cost garage
# - size garage
# - got detail wrong sorry seller advised garage ground floor collection drop
#
# Sentences containing 'garden':
# - drop back garden shed
# - greenhouse garden
# - garden
# - plastic lightweight garden bench delivering country
# - side entry address ground floor garden country
# - moved garden entry effort ecpxtremily light
# - interested buying garden plastic wood affect bench perfect condition thought may b able sell job
# - dismantled garden shed approve flat load side fix
# - back garden b front garden b
# - lift involved garden garden
# - stable matt garden box slim metal locker three bin
# - quite packed box small furniture item freezer plant garden item
# - need cooker range collecting macclesfield delivering internally hg removing old range leaving front garden
# - collection ground floor cottage delivery ground floor house step house long garden entrance house
# - double bed sofa set sweater sweater sweater dining table book case computer desk garden furniture small cabinet household item
# - king size bed mattress bed side table chest drawer mirror desk printer office chair bookcase shoe stand coat stand bathroom cabinet rug to stand small coffee table sweater sofa washing machine fridge freezer microwave dining table dining chair ad stand garden table garden chair parasol be chimney golf bag golf trolley garden tool lawnmower linen basket trimmer small to approve box
# - fridge garden bench garden wood burned burner
# - ground floor garden
# - flapjack king size bed king size mattress standard size box suitcase small medium large backpack dining room chair fold dining room table coffee table nest table curved chair garden bench office chair flat pack screen flat pack study desk x medium size plastic storage box wide bookcase narrow idea bookcase narrow cupboard carpet rug narrow drawer set sweater sofa coat stand
# - garage garden end stair lift
# - garden floor
# - garden floor
# - garden
# - garden
# - ground floor house approve step front garden path outside house
# - gonna dismantle approve keg going front garden
# - garden bench
# - garden
# - id like two drop possible first one b in second postcode b steel road sure exact ending that road nearby chest freezer two garden planter go b in mud kitchen around x x table around x x b
# - garden planter around x am x am
# - sweater sofa corner sofa king size bed chest drawer large crate household good crockery cutlery et egg chair garden furniture
# - garden
# - lightweight modern sofabed chest drawer medium lightweight sideboard small light chair lightweight modern small kitchen chair standard lamp to small round wire basket side table small console table microwave pan crockery food toaster kettle bedding laundry basket basket clothes towel book magazine tool medium light metal box garden tool like spade fork rake small picture wall mirror medium size plant small drawer bathroom cabinet slightly bigger drawer small cabinet
# - ground ground floor garden
# - back garden floor garden
# - floor straight garden
# - garden furniture table chair
# - ground floor garden
# - chair front garden
# - garden fence panel b house
# - need lift front door directly garden
# - straight store back garden
# - garden
# - around box to two small to bike lawn mower garden tool chair hostess trolley
# - two sweater sofa three sweater sofa double bed single bed desk triple wardrobe wardrobe chest drawer large box television stand television garden box garden swing washing machine cooker book stand flapjack wardrobe
# - small list garden furniture windy house
# - garden content presently stored container nothing huge heavy
# - ground floor garden
#
# Sentences containing 'home':
# - bought item yet need check still available home
# - know never husband friend take furniture home van
# - sweater sofa home daughter mile
# - delivery home knight
# - wardrobe pick idea sheffield home leister
# - destination lift home flat stair
# - would need specific time would confirm later care home care home job goalpost moving
# - would taken broomhill park flat nursing home the furniture understand left outside back building shall check exactly say reception
# - mean much cost totally dismantle furniture move new home assembly furniture
# - whichever cost extra home anyway
# - ago home flat the floor
# - home furniture
# - non lift would delivered home ground floor
# - specific get home till time would pick kyle
# - home
# - moving home large number box mostly book piece furniture shelf table chest drawer chair
# - working home
# - sure ground floor home
# - also bidet heel homestead brighten
# - ground floor ground floor sure nursing home lift
# - specific time going get back check nursing home see best
# - need move furniture two address currently living home two address pick furniture possible first address briar street l rob x it vivarium x ferret cage second address hutchinson walk l jaw x sofa sweater x double bed mattress are disassembled x large to stand x fridge freezer x washing machine
# - pick stationary bike gym bring home
# - collection home flat first floor lift
#
# Sentences containing 'level':
# - one level
# - ground level delivered ground level
# - ground level
# - ground level
# - street level going bungalow
# - street level
# - street level
# - lift needed ground level pick drop
# - ground level lift
# - put stuff bottom stair level new flat
# - one level
# - ground floor six step carry package street level
# - store self ground level cooker curry store foreside delivered amount it ground level kitchen u price plus
# - dismantling assembly large furniture item needed information property item moved living room x seat sofa x seat sofa x coffee table x upright piano x shelving unit item moved kitchen dining x dining table x chair x to bench x cupboard x to monitor item moved bedroom x medium box x chest drawer x chest drawer x bed storage x mattress item moved x bike pick address information type property house highest level property and floor drop address type property house highest level property it floor
# - pick piano cupboard ground floor want detail floor pick ground plus level drop ground plus level
# - storage ground level
# - ground level
# - going cemetery ground level
# - house house street level
# - house block top floor level
# - main door house lift street level
# - ground level house ground level bungalow
# - pick first floor drop ground level
# - sure think ground level
#
# Sentences containing 'pavement':
# - drop pavement
# - outside house ground floor recipient pavement outside would probably
# - ground floor pavement outside
#
# Sentences containing 'pickup':
# - men pickup drop stuff
# - pickup eh so going eh no minute drive
# - house need pickup chipstead road b drop handover road b
# - need discus pickup point person delivery point person get specific date time of thanks
# - help thevanandman to up chat pickup it delivery it city onion area onion query man van keyword device network apposition matchtype priciest headline expert removal onion creative random onion campaign id gelid to did judge
# - ground floor pickup delivery
# - close entry pickup could dropped close entry destination end
# - fine however machine paid pickup address l a first pay upfront giving machine please
# - ground floor pickup and floor drop lift
# - sure item waiting street pickup
# - ground floor pickup outside house actually
# - pickup
# - ground floor pickup ground floor delivery
# - pay delivery pickup
# - ground floor pickup floor delivery yes lift
# - pickup location and floor delivery ground floor
# - coming main door don't know main door pickup
#
# Sentences containing 'right':
# - right come back quote
# - right back in
# - set shelf dismantled hard say probably four unit approve am x am x am ten upright am thick mere high am deep shelf approve am long x am deep
# - yes one upright piano height am ground floor ground floor
# - may travel brighten trolley single way brolly delivery address
# - mean convenient get lift brighten trolley trolley yet may take lot time road
# - upright piano
# - right of get back of
# - need lift right back door
# - yes right
# - dismantling assembly large furniture item needed information property item moved living room x seat sofa x seat sofa x coffee table x upright piano x shelving unit item moved kitchen dining x dining table x chair x to bench x cupboard x to monitor item moved bedroom x medium box x chest drawer x chest drawer x bed storage x mattress item moved x bike pick address information type property house highest level property and floor drop address type property house highest level property it floor
# - sound right
# - book take payment right away day
# - ground floor parking access right outside door parking need are arranged security guy
# - sorry checking live need anything right
# - son moving possession leister brighten consist approximately cardboard box range bag mattress bit piece
# - thank info hope get right bid book regard cauline
# - right getting quote thanks
# - upright piano
# - know that right postcode new place chill
# - hi yes right
# - item upright piano
# - also bidet heel homestead brighten
# - right
#
# Sentences containing 'stair':
# - first floor lift wide staircase
# - hi rob three sweater sofa two chair nest small table chest drawer l l two seat sofa l a house l stair lift thanks
# - downstairs living room downstairs living room
# - ground floor flat stair leading flat
# - ground floor stair
# - one flight stair
# - two sweater sofa downstairs van council tip manhood l book slot
# - upstairs bedroom first floor lift remove leg try chop bit
# - first drop first floor apart stair
# - stair first floor
# - bed house bring everything upstairs stair removal people
# - upstairs could bring
# - delivery location ground floor may require take upstairs house
# - second floor lift stair
# - ground floor one item upstairs delivery address
# - stair also back gate completely flat
# - lift and floor flight stair
# - lift semi house item upstairs loft downstairs move item house needed
# - stair
# - stair
# - house converted flat shall stair flat
# - stair lift
# - nope house house stair lift
# - house main door street upstairs flight stair bedroom
# - main door main door carpet upstairs please bedroom
# - stored downstairs at
# - lift stair
# - upstairs house
# - stair
# - stair
# - need carried stair require two people people
# - upstairs bed room stair semi detached house
# - could possibly get taken downstairs
# - maybe taken downstairs
# - stair door
# - middle stair
# - it floor bedroom one flight stair lift happy move thing downstairs
# - bedroom shared house normal amount stair
# - it floor upstairs
# - first floor stair going house stair
# - bed wardrobe upstairs everything else stair
# - cheater draw upstairs well
# - upstairs room bed freezer kitchen downstairs
# - house living room stair
# - would first floor however stair leading house swell
# - well instead taking upstairs drop ground floor got lift anything upstairs
# - lift moving house house upstairs downstairs
# - lounge downstairs
# - two flight stair
# - drop set stair happy
# - stair pick drop
# - destination lift home flat stair
# - pick point ground floor drop point it floor stair
# - downstairs living room
# - house bottom floor dropped house get stair dad
# - need picked flat maybe stair n stay bottom flat stair
# - house upstairs bed wardrobe lift
# - need delivered house sure lifting stair required
# - put stuff bottom stair level new flat
# - stair coming front door
# - live bungalow stair daughter garage flat outside house
# - and floor small set stair doorway van
# - need wardrobe picked shop delivered also need old one taken downstairs
# - lift need carried downstairs
# - one house donegall road one flight stair
# - need lift round stair
# - upstairs lift
# - upstairs lift
# - lift house painting upstairs flight
# - nope stair
# - bungalow stair
# - and floor house straight internal stair main door destination bungalow
# - house the stuff downstairs
# - told contacted email mover dropping sofa knocking stair received information
# - top close takin ground stair
# - it floor maisonette buts massive set stair
# - it floor semi detached house lift well bed would need taken upstairs drawer chair table
# - upstairs house
# - it floor storage lift lounge house stair
# - apartment one set stair help
# - l we l so stair direct entry
# - house delivered garage front property lift stair involved
# - open flat stair block
# - house upstairs
# - would bring downstairs much would
# - spital entrance front road back car park lot stair flat lift
# - ground floor maisonette come back way use stair
# - say maisonette upstairs downstairs
# - it floor lift set stair
# - bed needed brought upstairs rest downstairs
# - sweater sofa dawn one flight stair sweater bedroom house
# - upstairs bedroom
# - sweater need arm taken get dawn stair outside taken away
# - sorry rob bit miked chair purchased habitat shop based sainsbury grain with stair
# - garage garden end stair lift
# - house stair lift
# - house stair lift
# - stair main door
# - manor house huge wide staircase
# - yes would fit going upstairs need dispose take mine
# - chest going stair hallway downstairs chest landing need furniture moving dropping
# - stairs
# - back way stair
# - ground floor house item transported back stair
# - bedroom flight stair
# - sorry connecting cooker removing old one taking stair outside lift
# - old fashioned to taken stair
# - floor stair lift
# - delivery maisonette flight stair and floor lift needed
# - basement flat lift take stair one floor
# - basement stair climb
# - ground floor stair outside house
# - flat shop stair bit steep managed get get stuff
# - upper cottage flat stair total
# - it floor going it floor stair
# - downstairs downstairs pick easy job
# - it floor flight stair lift
# - second floor tenement flat quite steep hill lift stair
# - one flight stair we p ground floor property we
# - main door house step bed drawer taken upstairs inside house
# - location stair leading house main door probably
# - first floor bedroom stair lift terraced house
# - ground floor well take everything upstairs
# - lift house unit upstairs
# - ground floor main door flat moving it floor main door flat accessed via flight outside stair
# - storage container stair
# - make sure item downstairs lift house
# - pick idleness road sorry door stair dropping c wellington road sorry it floor flat
# - fist floor second floor lift stair
# - ground floor ground floor stair
# - lift first floor set stair come main building
# - tenement one flight stair
# - two flight go stair
# - house staying stair stair need climb
# - ground floor stay proud floor stair going flat don't lift
# - thankyou still shopping around seems quite expensive wardrobe minute journey u leave bottom stair cheaper
# - destination ground floor apartment moving duplex ground floor basement bedroom item basement stair
# - ground floor uplift delivery two flight stair
# - round floor take upstairs
# - ground floor stair
# - house stair
# - g flight stair g stair g flight stair
# - g stair
# - one flight like upstairs house taking note size van half ton van name moral pirate partner collection point john machine
# - ground floor fine husband carry upstairs
# - house downstairs
# - bottom floor straight door main door stair
# - main door set stair bedroom stuff straight kitchen sitting room
# - one flight stair lift
# - set stair it floor help lift
# - i upstairs delivery
# - it floor small lift stairwell next
# - house ground floor stair involved
# - partner carry stair
# - ground floor block external stair
# - downstairs need pick bed
# - floor bungalow radiate spoke bed upstairs
# - upstairs lift leave outside door bottom stair
# - one set stair step
# - upstairs house
# - it floor lift upstairs villa
# - getting picked hillswick crescent melton house stair gran house outside
# - sorry would taken high rise flat castlebay drive flat melton lift go would stair walk get flat
# - flat shop one set stair jo lift
# - first floor flat going ground floor flat lift stair front door
# - first address front door house stair address going first floor lift
# - ground stair
# - item going stair house
# - the one set outside stair maisonette first floor
# - stair
# - pick ground floor stair drop it floor
# - first floor flight stair
# - house try get wardrobe stuff downstairs
# - well moving new house bedroom stuff go upstairs
# - sofa downstairs
# - basement lift around sheepish narrow stair
# - moving house item downstairs upstairs bedroom
# - first floor upstairs house lift
# - first floor flat stair lift floor
# - it floor stair tenement
# - first floor lift box to downstairs
# - normal house furniture removed upstairs downstairs
# - downstairs lift
# - bed upstairs lift
# - house lift item either downstairs upstairs
# - upstairs first floor
# - stair house
# - upstairs house lift
# - inch television going block three floor stair
# - the floor lift go the there wee set stair
# - first floor life stair
# - lift item picked it floor tenement spiral staircase taken second floor flat end tenement spiral case
# - downstairs room house help lifting end delivery first floor room
# - it floor block communal flat lift flight stair
# - small set stair lift
# - also stair pick he
# - side flat brother help lift one flight stair
# - first stayed stair
# - floor upstairs
# - think downstairs already
# - stair pick
#
# Sentences containing 'storage':
# - business move large printer requiring four people lift shelving storage unit
# - paper drill mainly box storage unit desk
# - x bedroom apartment furniture item living room bedroom moving stuff storage serviced apartment block
# - item medium storage box another storage container
# - garage ground floor ground floor storage unit
# - storage floor lift r first floor like bed near daresay b q
# - g ex would need storage unit chest drawer double bed mattress glass display unit to to unit small coffee table moved would need sweater couch moved g r delivery my or
# - pick house going storage unit ground floor
# - storage unit trolley need
# - needing furniture moved old property g so new property g a including additional furniture delivered storage unit g toy item moved old new property include sweater sofa single bed king size bed set bedroom drawer bedside table coffee table side table
# - storage unit take flat take want picked drop
# - storage unit lift trolley thing carry item and floor
# - approve box kitchen cabinet metal pull file cabinet first floor storage ground floor
# - remove one armchair storage house
# - it floor storage lift lounge house stair
# - fridge freezer sweater chesterfield sofa to stand sideboard x wooden armchair coffee table small fold dining table king size bed dismantled storage chest free standing clothes rail x chest drawer bedside unit daybed computer desk exercise bike
# - going storage locker placed outside carpark space
# - flapjack king size bed king size mattress standard size box suitcase small medium large backpack dining room chair fold dining room table coffee table nest table curved chair garden bench office chair flat pack screen flat pack study desk x medium size plastic storage box wide bookcase narrow idea bookcase narrow cupboard carpet rug narrow drawer set sweater sofa coat stand
# - don't know exact yet bough item lady sofa storage unit fashion line
# - change know time lady storage unit
# - ground floor residential ground floor storage center
# - flexible time day habitat closing soon day storage
# - dismantling assembly large furniture item needed information property item moved living room x seat sofa x seat sofa x coffee table x upright piano x shelving unit item moved kitchen dining x dining table x chair x to bench x cupboard x to monitor item moved bedroom x medium box x chest drawer x chest drawer x bed storage x mattress item moved x bike pick address information type property house highest level property and floor drop address type property house highest level property it floor
# - one king size bed without storage
# - entirely certain approximately small box medium box large box rucksack large suitcase small suitcase bedside table to computer monitor large blanket bag storage unit mere squared
# - moving bed house storage sweater piece suite double divan bed mattress metal double bed frame mattress wardrobe bed side table single bed
# - storage ground level
# - might put storage unit manchester
# - house upper bedroom front door new house going garage storage
# - squirrel storage turn red erdington chest freezer high street king heath ground floor
# - red floor large lift big yellow storage
# - need take mattress storage unit bring another back
# - one tall storage locker one chest drawer one book shelf
# - wardrobe desk shelving unit cube storage unit
# - small double divan bed mattress suitcase bag plastic storage draw
# - approximately medium box to small storage unit black bag rucksack small box
# - storage container stair
# - sure taken self storage location booked yet
# - wooden blanket chest to stand bed size cabinet medium storage box
# - two sweater sofa king size bed single bed fridge freezer tumble dryer storage side unit
# - need tonne futon van which long stuff storage required
# - hi sorry first post code wrong b it ground floor storage unit
# - washing machine fridge freezer small chest freezer microwave sweater leather corner suite come apart piece double bed already dismantled storage container content glass table small coffee table to boxed chest drawer pic small to stand small glass to stand set ladder last tub paint small cupboard mike
# - storage unit lift
# - need collecting storage unit flat
# - sure storage facility however sure easily accessible lift et
# - called big yellow self storage liverpool edge lane
# - edinburgh big yellow storage lift
# - storage unit red floor
# - ground floor lift needed delivery location storage unit
# - three sweater sofa double bed mattress two ottoman storage box
#
# Sentences containing 'street level':
# - street level going bungalow
# - street level
# - street level
# - ground floor six step carry package street level
# - house house street level
# - main door house lift street level

# %%
df_counts_sorted = df_counts.sort_values(by='Number of Sentences', ascending=False)
df_counts_sorted
# Out:
#             Word  Number of Sentences
# 12         stair                  201
# 2       delivery                  102
# 13       storage                   51
# 6         garden                   48
# 5         garage                   41
# 3     downstairs                   31
# 4     front door                   31
# 1       bungalow                   30
# 7           home                   24
# 8          level                   24
# 11         right                   24
# 10        pickup                   17
# 0       basement                    7
# 14  street level                    6
# 9       pavement                    3

# %%
# Function to count occurrences of each keyword or phrase in the corpus
def count_keyword_occurrences(corpus, keywords):
    # Convert the entire corpus into a single string for easier searching
    corpus_text = ' '.join(corpus).lower()
    
    # Initialize a dictionary to hold the count of occurrences for each keyword
    keyword_occurrences = {}
    
    # Loop through each keyword to find and count its occurrences in the corpus text
    for keyword in keywords:
        # Normalize keyword to ensure consistent matching
        normalized_keyword = keyword.lower()
        # Count occurrences of the keyword in the corpus text
        count = corpus_text.count(normalized_keyword)
        # Store the count in the dictionary
        keyword_occurrences[keyword] = count
    
    return keyword_occurrences

# Assuming corpus and corpus_key are defined as before
# Normalize keywords since we're dealing with exact matches
keywords = [keyword.lower() for keyword in corpus_key]

# Count occurrences of each keyword or phrase in the corpus
keyword_occurrences = count_keyword_occurrences(corpus, keywords)

# keyword_occurrences now contains the count of each keyword or phrase present in the corpus

# %%
# Assuming keyword_occurrences is the dictionary with keyword counts
keyword_occurrences_sorted = sorted(keyword_occurrences.items(), key=lambda x: x[1], reverse=True)

# Convert sorted list of tuples back to a dictionary if you prefer dictionary format
keyword_occurrences_sorted_dict = dict(keyword_occurrences_sorted)

# keyword_occurrences_sorted_dict now contains the sorted occurrences in decreasing order

# %%
keyword_occurrences_sorted_dict
# Out:
# {'stair': 224,
#  'delivery': 104,
#  'garden': 55,
#  'storage': 52,
#  'garage': 42,
#  'downstairs': 33,
#  'front door': 31,
#  'bungalow': 30,
#  'level': 29,
#  'home': 25,
#  'right': 24,
#  'pickup': 17,
#  'basement': 9,
#  'street level': 6,
#  'pavement': 3}
